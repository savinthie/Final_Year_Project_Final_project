# %% [markdown]
# <a href="https://colab.research.google.com/github/savinthie/Final_Year_Project_Final_project/blob/main/Final_IDP_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing of necessary libraries**

# %%
from tensorflow.keras.layers import Layer
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Flatten, Dense, ReLU, Concatenate, MaxPooling1D,Dropout
from tensorflow.keras.optimizers import Adam
import joblib
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
import xgboost as xgb
from tensorflow.keras.regularizers import l2
from tqdm import tqdm
from google.colab import drive
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
import pickle
#from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# **Data collection stage**

# %%
drive.mount('/content/drive')
original_household_dataset = pd.read_csv('/content/drive/MyDrive/FYP 2024 25/USDataset.csv', header=1)
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Data preprocessing stage**

# %%
# Data Preprocessing
original_household_dataset = original_household_dataset.fillna(0)
original_household_dataset.columns = [col.lower().replace(' ', '').replace('.', '') for col in original_household_dataset.columns]
cols_to_keep = ['stateabv', 'county', 'family', 'housing', 'food', 'transportation',
                'healthcare', 'othernecessities', 'childcare', 'taxes', 'total',
                'median_family_income', 'num_counties_in_st']
household_dataset = original_household_dataset[cols_to_keep].copy()

household_dataset['median_family_income'] = household_dataset['median_family_income'].replace(',', '', regex=True).astype(float)

# %% [markdown]
# **Feature engineering stage**

# %%
household_dataset['median_family_income'] = household_dataset['median_family_income'].map(lambda x: x/12)
household_dataset['n_parents'] = household_dataset['family'].str.slice(0, 1).astype(int)
household_dataset['n_children'] = household_dataset['family'].str.slice(2, 3).astype(int)
household_dataset['n_members'] = household_dataset['n_parents'] + household_dataset['n_children']
household_dataset['financial_stability'] = household_dataset['median_family_income'] / household_dataset['total']
household_dataset["per_member_cost"] = household_dataset["total"] / household_dataset["n_members"]
household_dataset["child_expense_cost"] = household_dataset["per_member_cost"]*household_dataset["n_children"]
household_dataset["parent_expense_cost"] = household_dataset["per_member_cost"]*household_dataset["n_parents"]
household_dataset["other_expense_cost"] = household_dataset["total"] - (household_dataset["child_expense_cost"]+household_dataset["parent_expense_cost"])
# fixing the 0 child issue
household_dataset["zero_childcare_cost"] = household_dataset['n_children'].map(lambda x: 0 if x < 1 else 1)

# %% [markdown]
# **Feature scaling (An important data handling technique in the Neural networks)**

# %%
# Splitting the data
X = household_dataset[['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents', 'n_members']+['per_member_cost','child_expense_cost','parent_expense_cost','other_expense_cost','zero_childcare_cost']].values
y_expenses = household_dataset[['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']].values

target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']

# Scaling
scaler_X = MinMaxScaler()

# Load the X scaler
# scaler_X = joblib.load('scaler_X.pkl')

X_scaled = scaler_X.fit_transform(X)

scaler_y = MinMaxScaler()

# Load the y scaler
# scaler_y = joblib.load('scaler_y.pkl')
y_exp_scaled = scaler_y.fit_transform(y_expenses)


# Save the X scaler
joblib.dump(scaler_X, 'scaler_X.pkl')

# Save the y scaler
joblib.dump(scaler_y, 'scaler_y.pkl')
# Out:
# ['scaler_y.pkl']

# %%
# this method is used to avoid the issue in the mape and smape value for the childcare expenses since the childcare expenses consist of 0 value where the smape and mape are sensitive of.
def replace_zeros_with_ones(a, b):
    # Iterate through both lists simultaneously
    for i in range(len(a)):
        # If both value is 0, replace both with 1
        if a[i] == 0 and b[i] == 0:
            a[i] = 1
            b[i] = 1
    return a, b

# %% [markdown]
# *This replace_zero_with_one function is used to handle the infinity values in the MAPE and SMAPE metrics int he Childcare expenses since the Childcare expense for the no child is 0*

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def calculateSmape(y_true, y_pred):
    y_true, y_pred = replace_zeros_with_ones(y_true, y_pred)
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    numerator = np.abs(y_true - y_pred)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    smape_value = np.mean(numerator / denominator) * 100
    return smape_value

# %%
# Cross-Validation Setup
kf = KFold(n_splits=5, shuffle=True, random_state=100)

# Metrics
def print_metrics(y_true, y_pred, task_name):
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"{task_name} - MSE: {mse:.4f}, R2: {r2:.4f}")

def regr_report(x, y):
    mae = round(mean_absolute_error(x, y), 4)
    r2 = round(r2_score(x, y), 4)
    mse = round(mean_squared_error(x, y), 4)
    rmse = round(np.sqrt(mean_squared_error(x, y)), 4)
    smape_score = calculateSmape(x, y)
    mape= round(mean_absolute_percentage_error(x, y), 4)
    return f'MAE: {mae}, R-Squared: {r2}, RMSE: {rmse}, MSE: {mse} ,smape: {smape_score}, mape: {mape}'

# %%
num_children_col = 3  # 4th position, 0-indexed
childcare_exp_col = target_col_list.index('childcare')  # Replace 'childcare_exp' with the actual target name

# %% [markdown]
# **Model selection stage**

# %% [markdown]
# **Decision tree**

# %%
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, model_type='decision_tree',max_depth=6):
    fold = 1
    childcarelist = []
    childcarelist_pred = []
    for train_index, val_index in kf.split(X_scaled):
        models = []
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        # Split validation and test data
        X_test, X_val, y_test, y_val = train_test_split(
            X_test_val, y_test_val, test_size=0.5, random_state=100
        )  # 50/50 split of remaining 20%

        # Train model for each target variable
        all_y_train_pred = []
        all_y_val_pred = []
        all_y_test_pred = []

        for i in range(y_train.shape[1]):
            model = DecisionTreeRegressor(max_depth=max_depth, random_state=100)
            model.fit(X_train, y_train[:, i])
            models.append(model)

            # Predictions
            y_train_pred = model.predict(X_train)
            y_val_pred = model.predict(X_val)
            y_test_pred = model.predict(X_test)

            # Append predictions for current target to the list
            all_y_train_pred.append(y_train_pred)
            all_y_val_pred.append(y_val_pred)
            all_y_test_pred.append(y_test_pred)

        # Stack predictions for all targets to get the original shape
        y_train_pred = np.column_stack(all_y_train_pred)
        y_val_pred = np.column_stack(all_y_val_pred)
        y_test_pred = np.column_stack(all_y_test_pred)

        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred)
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred)
        y_test_original = scaler_y.inverse_transform(y_test)

        # Enforce the rule after predictions for childcare expense
        y_train_pred_original[:, childcare_exp_col] = np.where(
            X_train[:, num_children_col] == 0, 0, y_train_pred_original[:, childcare_exp_col])

        y_val_pred_original[:, childcare_exp_col] = np.where(
            X_val[:, num_children_col] == 0, 0, y_val_pred_original[:, childcare_exp_col])

        y_test_pred_original[:, childcare_exp_col] = np.where(
            X_test[:, num_children_col] == 0, 0, y_test_pred_original[:, childcare_exp_col])

        # Metrics for each target
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize
# Test Data: MAE: 139.711, R-Squared: 0.831, RMSE: 198.3655, MSE: 39348.8839 ,smape: 11.401966831284858, mape: 11.6014
#
# Model Results for Othernecessities:
# Train Data: MAE: 42.3375, R-Squared: 0.9349, RMSE: 58.5051, MSE: 3422.8511 ,smape: 6.211309301146435, mape: 6.2357
# Validation Data: MAE: 42.8974, R-Squared: 0.9286, RMSE: 58.976, MSE: 3478.1731 ,smape: 6.24546955168505, mape: 6.264
# Test Data: MAE: 42.5008, R-Squared: 0.9336, RMSE: 59.1836, MSE: 3502.697 ,smape: 6.25236077245207, mape: 6.2808
#
# Model Results for Childcare:
# Train Data: MAE: 120.395, R-Squared: 0.9151, RMSE: 183.3086, MSE: 33602.0426 ,smape: 10.901377569958658, mape: 11.4109
# Validation Data: MAE: 124.4556, R-Squared: 0.9013, RMSE: 189.4321, MSE: 35884.5346 ,smape: 11.167790531843792, mape: 11.6798
# Test Data: MAE: 119.0599, R-Squared: 0.9155, RMSE: 181.1269, MSE: 32806.9484 ,smape: 10.8833910130801, mape: 11.4455
#
# Model Results for Taxes:
# Train Data: MAE: 71.9269, R-Squared: 0.9412, RMSE: 99.6517, MSE: 9930.4531 ,smape: 7.946933624359012, mape: 8.2114
# Validation Data: MAE: 74.7285, R-Squared: 0.9278, RMSE: 103.848, MSE: 10784.416 ,smape: 8.146260276148759, mape: 8.3961
# Test Data: MAE: 70.9037, R-Squared: 0.9418, RMSE: 99.554, MSE: 9910.9974 ,smape: 7.776585808924723, mape: 8.0

# %% [markdown]
# **Random forest regressor**

# %%
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, model_type='random_forest', n_estimators=100, max_depth=6):
    fold = 1
    childcarelist = []
    childcarelist_pred = []
    for train_index, val_index in kf.split(X_scaled):
        models = []
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        # Split validation and test data
        X_test, X_val, y_test, y_val = train_test_split(
            X_test_val, y_test_val, test_size=0.5, random_state=100
        )  # 50/50 split of remaining 20%

        # Train model for each target variable
        all_y_train_pred = []
        all_y_val_pred = []
        all_y_test_pred = []

        for i in range(y_train.shape[1]):
            model = RandomForestRegressor(n_estimators=n_estimators, max_depth=max_depth, random_state=100)
            model.fit(X_train, y_train[:, i])
            models.append(model)

            # Predictions
            y_train_pred = model.predict(X_train)
            y_val_pred = model.predict(X_val)
            y_test_pred = model.predict(X_test)

            # Append predictions for current target to the list
            all_y_train_pred.append(y_train_pred)
            all_y_val_pred.append(y_val_pred)
            all_y_test_pred.append(y_test_pred)

        # Stack predictions for all targets to get the original shape
        y_train_pred = np.column_stack(all_y_train_pred)
        y_val_pred = np.column_stack(all_y_val_pred)
        y_test_pred = np.column_stack(all_y_test_pred)

        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred)
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred)
        y_test_original = scaler_y.inverse_transform(y_test)

        # Enforce the rule after predictions for childcare expense
        y_train_pred_original[:, childcare_exp_col] = np.where(
            X_train[:, num_children_col] == 0, 0, y_train_pred_original[:, childcare_exp_col])

        y_val_pred_original[:, childcare_exp_col] = np.where(
            X_val[:, num_children_col] == 0, 0, y_val_pred_original[:, childcare_exp_col])

        y_test_pred_original[:, childcare_exp_col] = np.where(
            X_test[:, num_children_col] == 0, 0, y_test_pred_original[:, childcare_exp_col])

        # Metrics for each target
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize
# Validation Data: MAE: 138.8911, R-Squared: 0.8422, RMSE: 198.2959, MSE: 39321.2566 ,smape: 11.080681495955732, mape: 11.2632
# Test Data: MAE: 135.5888, R-Squared: 0.838, RMSE: 194.1704, MSE: 37702.1472 ,smape: 11.079134933164562, mape: 11.2728
#
# Model Results for Othernecessities:
# Train Data: MAE: 40.2527, R-Squared: 0.9407, RMSE: 55.8512, MSE: 3119.3522 ,smape: 5.902760876862458, mape: 5.9275
# Validation Data: MAE: 40.6945, R-Squared: 0.9356, RMSE: 56.0233, MSE: 3138.6147 ,smape: 5.921193116593451, mape: 5.9373
# Test Data: MAE: 40.123, R-Squared: 0.9404, RMSE: 56.0696, MSE: 3143.7965 ,smape: 5.907202248618738, mape: 5.932
#
# Model Results for Childcare:
# Train Data: MAE: 115.7233, R-Squared: 0.9232, RMSE: 174.4266, MSE: 30424.6444 ,smape: 10.491707711493017, mape: 10.9666
# Validation Data: MAE: 117.7233, R-Squared: 0.9128, RMSE: 178.0985, MSE: 31719.0699 ,smape: 10.621999540420626, mape: 11.0928
# Test Data: MAE: 115.6252, R-Squared: 0.9208, RMSE: 175.4514, MSE: 30783.2075 ,smape: 10.54577454338756, mape: 11.077
#
# Model Results for Taxes:
# Train Data: MAE: 64.6026, R-Squared: 0.9515, RMSE: 90.523, MSE: 8194.4101 ,smape: 7.205107903293649, mape: 7.4833
# Validation Data: MAE: 66.3318, R-Squared: 0.9411, RMSE: 93.8083, MSE: 8799.9949 ,smape: 7.2863956760361335, mape: 7.5511
# Test Data: MAE: 63.7744, R-Squared: 0.9525, RMSE: 89.9087, MSE: 8083.5816 ,smape: 7.052968522392733, mape: 7.2867

# %% [markdown]
# *Implementation of the Novel hybrid model*

# %% [markdown]
# **1D CNN-MLP Hybrid model**

# %%
# L2 regularization strength (you can tune this value)
l2_strength = 0.01
# Hybrid Model Definition
def create_hybrid_model(input_shape, output_shape):
    input_layer = Input(shape=input_shape)
    # CNN part
    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu')(input_layer)
    x = Flatten()(x)
    # MLP part
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    # Multiple regression outputs
    output_layers = [Dense(1, activation='linear', name=f'target_{col}')(x) for col in target_col_list]

    model = Model(inputs=input_layer, outputs=output_layers)
    return model

# %%
global X_train_global, X_test_global, X_val_global
global y_train_global, y_test_global, y_val_global

# %%
# Cross-Validation with Evaluation
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_epochs=200):
    global X_train_global, X_test_global, X_val_global
    global y_train_global, y_test_global, y_val_global
    fold = 1
    for train_index, val_index in kf.split(X_scaled):
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5, random_state=100) # 50/50 split of remaining 20%

        X_train_global, X_test_global, X_val_global = X_train, X_test, X_val
        y_train_global, y_test_global, y_val_global = y_train, y_test, y_val

        # Reshaping data for CNN
        X_train = X_train[..., np.newaxis]
        X_val = X_val[..., np.newaxis]
        X_test = X_test[..., np.newaxis]

        model = create_hybrid_model((X_train.shape[1], 1), y_train.shape[1])
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

        model.summary()

        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

        # Training
        model.fit(X_train, [y_train[:, i] for i in range(y_train.shape[1])],
                  validation_data=(X_val, [y_val[:, i] for i in range(y_val.shape[1])]),
                  epochs=num_epochs, batch_size=64, verbose=1, callbacks= [early_stopping])

        # Predictions
        y_train_pred = np.column_stack(model.predict(X_train))
        y_val_pred = np.column_stack(model.predict(X_val))
        y_test_pred = np.column_stack(model.predict(X_test)) #Prediction on test set

        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred)
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred) #Inverse transform for test set
        y_test_original = scaler_y.inverse_transform(y_test) #Inverse transform for test set

        # Enforce the rule after predictions for childcare expense
        # The issue is likely caused by X_train having an extra dimension due to[..., np.newaxis].
        # We need to select the original features for the condition
        y_train_pred_original[:, childcare_exp_col] = np.where(
            X_train[:, num_children_col, 0] == 0, 0, y_train_pred_original[:, childcare_exp_col]) #Using X_train[:, num_children_col, 0] instead of X_train[:, num_children_col]

        y_val_pred_original[:, childcare_exp_col] = np.where(
            X_val[:, num_children_col, 0] == 0, 0, y_val_pred_original[:, childcare_exp_col]) #Using X_val[:, num_children_col, 0] instead of X_val[:, num_children_col]

        y_test_pred_original[:, childcare_exp_col] = np.where(
            X_test[:, num_children_col, 0] == 0, 0, y_test_pred_original[:, childcare_exp_col]) #Using X_test[:, num_children_col, 0] instead of X_test[:, num_children_col]

        # Metrics for each target
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize()}:')
            print('Train Data:', regr_report(y_train_original[:, i], y_train_pred_original[:, i]))
            print('Validation Data:', regr_report(y_val_original[:, i], y_val_pred_original[:, i]))
            print('Test Data:', regr_report(y_test_original[:, i], y_test_pred_original[:, i])) #Print metrics for test set
            print()

        fold += 1
    return model

model_combine = cross_val_with_evaluation(X_scaled, y_exp_scaled,kf)
# Out:
# Fold 1/5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 11, 1)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 11, 8)          │             32 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 88)             │              0 │ conv1d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 128)            │         11,392 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 64)             │          8,256 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_housing (Dense)    │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_food (Dense)       │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_transportation     │ (None, 1)              │             65 │ dense_1[0][0]          │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_healthcare (Dense) │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_othernecessities   │ (None, 1)              │             65 │ dense_1[0][0]          │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_childcare (Dense)  │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_taxes (Dense)      │ (None, 1)              │             65 │ dense_1[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 20,135 (78.65 KB)
#  Trainable params: 20,135 (78.65 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0554 - target_childcare_loss: 0.0103 - target_food_loss: 0.0030 - target_healthcare_loss: 0.0145 - target_housing_loss: 0.0041 - target_othernecessities_loss: 0.0095 - target_taxes_loss: 0.0043 - target_transportation_loss: 0.0098 - val_loss: 0.0142 - val_target_childcare_loss: 0.0022 - val_target_food_loss: 4.9231e-04 - val_target_healthcare_loss: 0.0051 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 8.5343e-04 - val_target_taxes_loss: 5.5782e-04 - val_target_transportation_loss: 0.0037
# Epoch 2/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.
# Train Data: MAE: 32.1379, R-Squared: 0.9605, RMSE: 45.6105, MSE: 2080.3176 ,smape: 4.737212534642029, mape: 4.7373
# Validation Data: MAE: 32.251, R-Squared: 0.9582, RMSE: 45.16, MSE: 2039.4241 ,smape: 4.730376918207021, mape: 4.723
# Test Data: MAE: 32.2851, R-Squared: 0.9586, RMSE: 46.7295, MSE: 2183.6496 ,smape: 4.763489939772886, mape: 4.7679
#
# Model Results for Childcare:
# Train Data: MAE: 91.9488, R-Squared: 0.9483, RMSE: 143.0767, MSE: 20470.9563 ,smape: 8.254559023900477, mape: 8.3061
# Validation Data: MAE: 91.8354, R-Squared: 0.9462, RMSE: 139.8248, MSE: 19550.9737 ,smape: 8.365177031667516, mape: 8.4527
# Test Data: MAE: 90.3572, R-Squared: 0.947, RMSE: 143.47, MSE: 20583.6483 ,smape: 8.1739907693564, mape: 8.2787
#
# Model Results for Taxes:
# Train Data: MAE: 48.1852, R-Squared: 0.9713, RMSE: 69.6183, MSE: 4846.7081 ,smape: 5.336749132955704, mape: 5.4351
# Validation Data: MAE: 49.7367, R-Squared: 0.9649, RMSE: 72.4155, MSE: 5243.9975 ,smape: 5.440923031859122, mape: 5.5249
# Test Data: MAE: 47.1663, R-Squared: 0.9726, RMSE: 68.2448, MSE: 4657.357 ,smape: 5.23113940196853, mape: 5.3226

# %% [markdown]
# **XGBoost**

# %%
# Cross-Validation with Evaluation for XGBoost
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_boost_rounds=4000):
    fold = 1
    childcarelist = []
    childcarelist_pred = []
    for train_index, val_index in kf.split(X_scaled):
        models = []
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        # Split validation and test data
        X_test, X_val, y_test, y_val = train_test_split(
            X_test_val, y_test_val, test_size=0.5, random_state=100
        )  # 50/50 split of remaining 20%

        # Train XGBoost model for each target variable
        # Store predictions for all targets in this fold
        all_y_train_pred = []
        all_y_val_pred = []
        all_y_test_pred = []

        for i in range(y_train.shape[1]):
            dtrain = xgb.DMatrix(X_train, label=y_train[:, i])
            dval = xgb.DMatrix(X_val, label=y_val[:, i])
            dtest = xgb.DMatrix(X_test)

            params = {
                'objective': 'reg:squarederror',
                'eval_metric': 'rmse',
                'learning_rate': 0.01,
                'max_depth': 6,
                'n_estimators': num_boost_rounds
            }

            evals = [(dtrain, 'train'), (dval, 'eval')]
            model = xgb.train(
                params, dtrain, num_boost_rounds, evals, early_stopping_rounds=50, verbose_eval=50
            )
            models.append(model) #Not required here

            # Predictions
            y_train_pred = model.predict(dtrain)
            y_val_pred = model.predict(dval)
            y_test_pred = model.predict(dtest)

            # Append predictions for current target to the list
            all_y_train_pred.append(y_train_pred)
            all_y_val_pred.append(y_val_pred)
            all_y_test_pred.append(y_test_pred)

        # Stack predictions for all targets to get the original shape
        y_train_pred = np.column_stack(all_y_train_pred)
        y_val_pred = np.column_stack(all_y_val_pred)
        y_test_pred = np.column_stack(all_y_test_pred)

        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred) #Now y_train_pred has 7 columns matching scaler_y
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)  #Now y_val_pred has 7 columns matching scaler_y
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred) #Now y_test_pred has 7 columns matching scaler_y
        y_test_original = scaler_y.inverse_transform(y_test)


        # Enforce the rule after predictions for childcare expense
        y_train_pred_original[:, childcare_exp_col] = np.where(
            X_train[:, num_children_col] == 0, 0, y_train_pred_original[:, childcare_exp_col])

        y_val_pred_original[:, childcare_exp_col] = np.where(
            X_val[:, num_children_col] == 0, 0, y_val_pred_original[:, childcare_exp_col])

        y_test_pred_original[:, childcare_exp_col] = np.where(
            X_test[:, num_children_col] == 0, 0, y_test_pred_original[:, childcare_exp_col])

        # Metrics for each target
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize()}:')
            print('Train Data:', regr_report(y_train_original[:, i], y_train_pred_original[:, i]))
            print('Validation Data:', regr_report(y_val_original[:, i], y_val_pred_original[:, i]))
            print('Test Data:', regr_report(y_test_original[:, i], y_test_pred_original[:, i])) #Print metrics for test set
            print()

        fold += 1
    return models

# Cross-Validation Execution
xgb_models = cross_val_with_evaluation(X_scaled, y_exp_scaled, kf)
# Out:
# Fold 1/5
# [0]	train-rmse:0.09576	eval-rmse:0.09357
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:723: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:37:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.06498	eval-rmse:0.06382
# [100]	train-rmse:0.04792	eval-rmse:0.04759
# [150]	train-rmse:0.03894	eval-rmse:0.03937
# [200]	train-rmse:0.03424	eval-rmse:0.03522
# [250]	train-rmse:0.03154	eval-rmse:0.03279
# [300]	train-rmse:0.02986	eval-rmse:0.03120
# [350]	train-rmse:0.02847	eval-rmse:0.02993
# [400]	train-rmse:0.02729	eval-rmse:0.02883
# [450]	train-rmse:0.02634	eval-rmse:0.02797
# [500]	train-rmse:0.02578	eval-rmse:0.02749
# [550]	train-rmse:0.02528	eval-rmse:0.02708
# [600]	train-rmse:0.02482	eval-rmse:0.02670
# [650]	train-rmse:0.02448	eval-rmse:0.02645
# [700]	train-rmse:0.02410	eval-rmse:0.02616
# [750]	train-rmse:0.02364	eval-rmse:0.02578
# [800]	train-rmse:0.02330	eval-rmse:0.02550
# [850]	train-rmse:0.02298	eval-rmse:0.02523
# [900]	train-rmse:0.02266	eval-rmse:0.02493
# [950]	train-rmse:0.02233	eval-rmse:0.02463
# [1000]	train-rmse:0.02201	eval-rmse:0.02431
# [1050]	train-rmse:0.02180	eval-rmse:0.02412
# [1100]	train-rmse:0.02156	eval-rmse:0.02391
# [1150]	train-rmse:0.02134	eval-rmse:0.02374
# [1200]	train-rmse:0.02116	eval-rmse:0.02362
# [1250]	train-rmse:0.02098	eval-rmse:0.02348
# [1300]	train-rmse:0.02082	eval-rmse:0.02334
# [1350]	train-rmse:0.02064	eval-rmse:0.02318
# [1400]	train-rmse:0.02050	eval-rmse:0.02308
# [1450]	train-rmse:0.02034	eval-rmse:0.02297
# [1500]	train-rmse:0.02022	eval-rmse:0.02289
# [1550]	train-rmse:0.02009	eval-rmse:0.02281
# [1600]	train-rmse:0.01995	eval-rmse:0.02271
# [1650]	train-rmse:0.01981	eval-rmse:0.02262
# [1700]	train-rmse:0.01964	eval-rmse:0.02251
# [1750]	train-rmse:0.01953	eval-rmse:0.02245
# [1800]	train-rmse:0.01943	eval-rmse:0.02241
# [1850]	train-rmse:0.01932	eval-rmse:0.02236
# [1900]	train-rmse:0.01922	eval-rmse:0.02229
# [1950]	train-rmse:0.01912	eval-rmse:0.02223
# [2000]	train-rmse:0.01903	eval-rmse:0.02219
# [2050]	train-rmse:0.01894	eval-rmse:0.02215
# [2100]	train-rmse:0.01882	eval-rmse:0.02207
# [2150]	train-rmse:0.01872	eval-rmse:0.02201
# [2200]	train-rmse:0.01862	eval-rmse:0.02196
# [2250]	train-rmse:0.01851	eval-rmse:0.02189
# [2300]	train-rmse:0.01842	eval-rmse:0.02185
# [2350]	train-rmse:0.01834	eval-rmse:0.02181
# [2400]	train-rmse:0.01826	eval-rmse:0.02177
# [2450]	train-rmse:0.01818	eval-rmse:0.02172
# [2500]	train-rmse:0.01809	eval-rmse:0.02167
# [2550]	train-rmse:0.01799	eval-rmse:0.02162
# [2600]	train-rmse:0.01791	eval-rmse:0.02159
# [2650]	train-rmse:0.01782	eval-rmse:0.02155
# [2700]	train-rmse:0.01773	eval-rmse:0.02150
# [2750]	train-rmse:0.01764	eval-rmse:0.02145
# [2800]	train-rmse:0.01757	eval-rmse:0.02143
# [2850]	train-rmse:0.01751	eval-rmse:0.02141
# [2900]	train-rmse:0.01743	eval-rmse:0.02136
# [2950]	train-rmse:0.01734	eval-rmse:0.02131
# [3000]	train-rmse:0.01725	eval-rmse:0.02125
# [3050]	train-rmse:0.01718	eval-rmse:0.02121
# [3100]	train-rmse:0.01711	eval-rmse:0.02118
# [3150]	train-rmse:0.01703	eval-rmse:0.02114
# [3200]	train-rmse:0.01695	eval-rmse:0.02109
# [3250]	train-rmse:0.01686	eval-rmse:0.02103
# [3300]	train-rmse:0.01678	eval-rmse:0.02099
# [3350]	train-rmse:0.01670	eval-rmse:0.02094
# [3400]	train-rmse:0.01663	eval-rmse:0.02090
# [3450]	train-rmse:0.01656	eval-rmse:0.02086
# [3500]	train-rmse:0.01651	eval-rmse:0.02084
# [3550]	train-rmse:0.01646	eval-rmse:0.02082
# [3600]	train-rmse:0.01642	eval-rmse:0.02081
# [3650]	train-rmse:0.01635	eval-rmse:0.02077
# [3700]	train-rmse:0.01630	eval-rmse:0.02076
# [3750]	train-rmse:0.01624	eval-rmse:0.02075
# [3800]	train-rmse:0.01618	eval-rmse:0.02073
# [3850]	train-rmse:0.01610	eval-rmse:0.02069
# [3900]	train-rmse:0.01606	eval-rmse:0.02068
# [3950]	train-rmse:0.01599	eval-rmse:0.02065
# [3999]	train-rmse:0.01593	eval-rmse:0.02063
# [0]	train-rmse:0.11587	eval-rmse:0.11470
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:37:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.07255	eval-rmse:0.07138
# [100]	train-rmse:0.04744	eval-rmse:0.04623
# [150]	train-rmse:0.03361	eval-rmse:0.03239
# [200]	train-rmse:0.02653	eval-rmse:0.02541
# [250]	train-rmse:0.02301	eval-rmse:0.02213
# [300]	train-rmse:0.02126	eval-rmse:0.02061
# [350]	train-rmse:0.02031	eval-rmse:0.01991
# [400]	train-rmse:0.01966	eval-rmse:0.01947
# [450]	train-rmse:0.01921	eval-rmse:0.01918
# [500]	train-rmse:0.01879	eval-rmse:0.01891
# [550]	train-rmse:0.01844	eval-rmse:0.01869
# [600]	train-rmse:0.01817	eval-rmse:0.01853
# [650]	train-rmse:0.01786	eval-rmse:0.01831
# [700]	train-rmse:0.01754	eval-rmse:0.01812
# [750]	train-rmse:0.01726	eval-rmse:0.01797
# [800]	train-rmse:0.01705	eval-rmse:0.01786
# [850]	train-rmse:0.01683	eval-rmse:0.01773
# [900]	train-rmse:0.01661	eval-rmse:0.01763
# [950]	train-rmse:0.01643	eval-rmse:0.01754
# [1000]	train-rmse:0.01623	eval-rmse:0.01744
# [1050]	train-rmse:0.01606	eval-rmse:0.01735
# [1100]	train-rmse:0.01590	eval-rmse:0.01728
# [1150]	train-rmse:0.01575	eval-rmse:0.01723
# [1200]	train-rmse:0.01562	eval-rmse:0.01717
# [1250]	train-rmse:0.01549	eval-rmse:0.01711
# [1300]	train-rmse:0.01536	eval-rmse:0.01706
# [1350]	train-rmse:0.01525	eval-rmse:0.01701
# [1400]	train-rmse:0.01514	eval-rmse:0.01696
# [1450]	train-rmse:0.01502	eval-rmse:0.01692
# [1500]	train-rmse:0.01489	eval-rmse:0.01687
# [1550]	train-rmse:0.01480	eval-rmse:0.01684
# [1600]	train-rmse:0.01470	eval-rmse:0.01681
# [1650]	train-rmse:0.01462	eval-rmse:0.01676
# [1700]	train-rmse:0.01452	eval-rmse:0.01671
# [1750]	train-rmse:0.01444	eval-rmse:0.01667
# [1800]	train-rmse:0.01435	eval-rmse:0.01663
# [1850]	train-rmse:0.01428	eval-rmse:0.01661
# [1900]	train-rmse:0.01420	eval-rmse:0.01658
# [1950]	train-rmse:0.01409	eval-rmse:0.01652
# [2000]	train-rmse:0.01397	eval-rmse:0.01644
# [2050]	train-rmse:0.01390	eval-rmse:0.01643
# [2100]	train-rmse:0.01383	eval-rmse:0.01641
# [2150]	train-rmse:0.01376	eval-rmse:0.01638
# [2200]	train-rmse:0.01367	eval-rmse:0.01634
# [2250]	train-rmse:0.01360	eval-rmse:0.01630
# [2300]	train-rmse:0.01352	eval-rmse:0.01627
# [2350]	train-rmse:0.01345	eval-rmse:0.01623
# [2400]	train-rmse:0.01338	eval-rmse:0.01621
# [2450]	train-rmse:0.01331	eval-rmse:0.01618
# [2500]	train-rmse:0.01325	eval-rmse:0.01615
# [2550]	train-rmse:0.01320	eval-rmse:0.01614
# [2600]	train-rmse:0.01314	eval-rmse:0.01613
# [2650]	train-rmse:0.01307	eval-rmse:0.01610
# [2700]	train-rmse:0.01302	eval-rmse:0.01609
# [2750]	train-rmse:0.01296	eval-rmse:0.01608
# [2800]	train-rmse:0.01291	eval-rmse:0.01606
# [2850]	train-rmse:0.01285	eval-rmse:0.01603
# [2900]	train-rmse:0.01278	eval-rmse:0.01600
# [2950]	train-rmse:0.01273	eval-rmse:0.01598
# [3000]	train-rmse:0.01266	eval-rmse:0.01594
# [3050]	train-rmse:0.01260	eval-rmse:0.01591
# [3100]	train-rmse:0.01254	eval-rmse:0.01588
# [3150]	train-rmse:0.01248	eval-rmse:0.01587
# [3200]	train-rmse:0.01242	eval-rmse:0.01585
# [3250]	train-rmse:0.01236	eval-rmse:0.01583
# [3300]	train-rmse:0.01232	eval-rmse:0.01582
# [3350]	train-rmse:0.01227	eval-rmse:0.01581
# [3400]	train-rmse:0.01223	eval-rmse:0.01581
# [3450]	train-rmse:0.01219	eval-rmse:0.01581
# [3500]	train-rmse:0.01215	eval-rmse:0.01580
# [3550]	train-rmse:0.01211	eval-rmse:0.01578
# [3600]	train-rmse:0.01205	eval-rmse:0.01574
# [3650]	train-rmse:0.01200	eval-rmse:0.01573
# [3700]	train-rmse:0.01194	eval-rmse:0.01570
# [3750]	train-rmse:0.01190	eval-rmse:0.01569
# [3800]	train-rmse:0.01187	eval-rmse:0.01569
# [3850]	train-rmse:0.01183	eval-rmse:0.01567
# [3900]	train-rmse:0.01178	eval-rmse:0.01566
# [3950]	train-rmse:0.01174	eval-rmse:0.01564
# [3999]	train-rmse:0.01169	eval-rmse:0.01562
# [0]	train-rmse:0.09852	eval-rmse:0.09932
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:38:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.07425	eval-rmse:0.07564
# [100]	train-rmse:0.06247	eval-rmse:0.06458
# [150]	train-rmse:0.05688	eval-rmse:0.05955
# [200]	train-rmse:0.05397	eval-rmse:0.05694
# [250]	train-rmse:0.05206	eval-rmse:0.05511
# [300]	train-rmse:0.05054	eval-rmse:0.05370
# [350]	train-rmse:0.04926	eval-rmse:0.05258
# [400]	train-rmse:0.04831	eval-rmse:0.05177
# [450]	train-rmse:0.04736	eval-rmse:0.05089
# [500]	train-rmse:0.04649	eval-rmse:0.05012
# [550]	train-rmse:0.04557	eval-rmse:0.04930
# [600]	train-rmse:0.04489	eval-rmse:0.04867
# [650]	train-rmse:0.04405	eval-rmse:0.04792
# [700]	train-rmse:0.04343	eval-rmse:0.04736
# [750]	train-rmse:0.04295	eval-rmse:0.04692
# [800]	train-rmse:0.04241	eval-rmse:0.04645
# [850]	train-rmse:0.04200	eval-rmse:0.04610
# [900]	train-rmse:0.04162	eval-rmse:0.04577
# [950]	train-rmse:0.04125	eval-rmse:0.04545
# [1000]	train-rmse:0.04086	eval-rmse:0.04512
# [1050]	train-rmse:0.04053	eval-rmse:0.04483
# [1100]	train-rmse:0.04020	eval-rmse:0.04458
# [1150]	train-rmse:0.03991	eval-rmse:0.04436
# [1200]	train-rmse:0.03966	eval-rmse:0.04417
# [1250]	train-rmse:0.03930	eval-rmse:0.04387
# [1300]	train-rmse:0.03904	eval-rmse:0.04368
# [1350]	train-rmse:0.03871	eval-rmse:0.04343
# [1400]	train-rmse:0.03843	eval-rmse:0.04321
# [1450]	train-rmse:0.03811	eval-rmse:0.04294
# [1500]	train-rmse:0.03787	eval-rmse:0.04276
# [1550]	train-rmse:0.03753	eval-rmse:0.04249
# [1600]	train-rmse:0.03722	eval-rmse:0.04228
# [1650]	train-rmse:0.03692	eval-rmse:0.04204
# [1700]	train-rmse:0.03670	eval-rmse:0.04192
# [1750]	train-rmse:0.03645	eval-rmse:0.04174
# [1800]	train-rmse:0.03618	eval-rmse:0.04154
# [1850]	train-rmse:0.03596	eval-rmse:0.04140
# [1900]	train-rmse:0.03571	eval-rmse:0.04122
# [1950]	train-rmse:0.03547	eval-rmse:0.04108
# [2000]	train-rmse:0.03527	eval-rmse:0.04094
# [2050]	train-rmse:0.03509	eval-rmse:0.04084
# [2100]	train-rmse:0.03491	eval-rmse:0.04073
# [2150]	train-rmse:0.03476	eval-rmse:0.04065
# [2200]	train-rmse:0.03461	eval-rmse:0.04058
# [2250]	train-rmse:0.03447	eval-rmse:0.04053
# [2300]	train-rmse:0.03429	eval-rmse:0.04045
# [2350]	train-rmse:0.03410	eval-rmse:0.04034
# [2400]	train-rmse:0.03394	eval-rmse:0.04027
# [2450]	train-rmse:0.03376	eval-rmse:0.04019
# [2500]	train-rmse:0.03362	eval-rmse:0.04012
# [2550]	train-rmse:0.03348	eval-rmse:0.04005
# [2600]	train-rmse:0.03332	eval-rmse:0.03995
# [2650]	train-rmse:0.03316	eval-rmse:0.03987
# [2700]	train-rmse:0.03303	eval-rmse:0.03980
# [2750]	train-rmse:0.03288	eval-rmse:0.03971
# [2800]	train-rmse:0.03276	eval-rmse:0.03964
# [2850]	train-rmse:0.03263	eval-rmse:0.03957
# [2900]	train-rmse:0.03248	eval-rmse:0.03946
# [2950]	train-rmse:0.03236	eval-rmse:0.03941
# [3000]	train-rmse:0.03219	eval-rmse:0.03931
# [3050]	train-rmse:0.03196	eval-rmse:0.03917
# [3100]	train-rmse:0.03179	eval-rmse:0.03911
# [3150]	train-rmse:0.03168	eval-rmse:0.03906
# [3200]	train-rmse:0.03154	eval-rmse:0.03898
# [3250]	train-rmse:0.03140	eval-rmse:0.03889
# [3300]	train-rmse:0.03124	eval-rmse:0.03879
# [3350]	train-rmse:0.03112	eval-rmse:0.03873
# [3400]	train-rmse:0.03100	eval-rmse:0.03868
# [3450]	train-rmse:0.03089	eval-rmse:0.03863
# [3500]	train-rmse:0.03077	eval-rmse:0.03858
# [3550]	train-rmse:0.03065	eval-rmse:0.03852
# [3600]	train-rmse:0.03054	eval-rmse:0.03846
# [3650]	train-rmse:0.03036	eval-rmse:0.03834
# [3700]	train-rmse:0.03021	eval-rmse:0.03825
# [3750]	train-rmse:0.03007	eval-rmse:0.03817
# [3800]	train-rmse:0.02996	eval-rmse:0.03813
# [3850]	train-rmse:0.02985	eval-rmse:0.03808
# [3900]	train-rmse:0.02974	eval-rmse:0.03804
# [3950]	train-rmse:0.02966	eval-rmse:0.03802
# [3999]	train-rmse:0.02958	eval-rmse:0.03800
# [0]	train-rmse:0.15675	eval-rmse:0.15624
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:38:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.10823	eval-rmse:0.10734
# [100]	train-rmse:0.08253	eval-rmse:0.08148
# [150]	train-rmse:0.06934	eval-rmse:0.06845
# [200]	train-rmse:0.06187	eval-rmse:0.06123
# [250]	train-rmse:0.05592	eval-rmse:0.05552
# [300]	train-rmse:0.05132	eval-rmse:0.05104
# [350]	train-rmse:0.04789	eval-rmse:0.04796
# [400]	train-rmse:0.04496	eval-rmse:0.04538
# [450]	train-rmse:0.04283	eval-rmse:0.04343
# [500]	train-rmse:0.04133	eval-rmse:0.04207
# [550]	train-rmse:0.04003	eval-rmse:0.04094
# [600]	train-rmse:0.03885	eval-rmse:0.03989
# [650]	train-rmse:0.03785	eval-rmse:0.03904
# [700]	train-rmse:0.03712	eval-rmse:0.03846
# [750]	train-rmse:0.03642	eval-rmse:0.03791
# [800]	train-rmse:0.03588	eval-rmse:0.03748
# [850]	train-rmse:0.03539	eval-rmse:0.03709
# [900]	train-rmse:0.03490	eval-rmse:0.03671
# [950]	train-rmse:0.03449	eval-rmse:0.03643
# [1000]	train-rmse:0.03414	eval-rmse:0.03618
# [1050]	train-rmse:0.03381	eval-rmse:0.03593
# [1100]	train-rmse:0.03352	eval-rmse:0.03573
# [1150]	train-rmse:0.03327	eval-rmse:0.03557
# [1200]	train-rmse:0.03301	eval-rmse:0.03542
# [1250]	train-rmse:0.03274	eval-rmse:0.03524
# [1300]	train-rmse:0.03248	eval-rmse:0.03509
# [1350]	train-rmse:0.03226	eval-rmse:0.03496
# [1400]	train-rmse:0.03207	eval-rmse:0.03483
# [1450]	train-rmse:0.03187	eval-rmse:0.03466
# [1500]	train-rmse:0.03164	eval-rmse:0.03450
# [1550]	train-rmse:0.03144	eval-rmse:0.03436
# [1600]	train-rmse:0.03125	eval-rmse:0.03424
# [1650]	train-rmse:0.03107	eval-rmse:0.03412
# [1700]	train-rmse:0.03091	eval-rmse:0.03401
# [1750]	train-rmse:0.03074	eval-rmse:0.03389
# [1800]	train-rmse:0.03055	eval-rmse:0.03377
# [1850]	train-rmse:0.03039	eval-rmse:0.03368
# [1900]	train-rmse:0.03024	eval-rmse:0.03361
# [1950]	train-rmse:0.03009	eval-rmse:0.03351
# [2000]	train-rmse:0.02991	eval-rmse:0.03342
# [2050]	train-rmse:0.02971	eval-rmse:0.03331
# [2100]	train-rmse:0.02953	eval-rmse:0.03320
# [2150]	train-rmse:0.02932	eval-rmse:0.03306
# [2200]	train-rmse:0.02913	eval-rmse:0.03295
# [2250]	train-rmse:0.02892	eval-rmse:0.03283
# [2300]	train-rmse:0.02875	eval-rmse:0.03277
# [2350]	train-rmse:0.02862	eval-rmse:0.03272
# [2400]	train-rmse:0.02846	eval-rmse:0.03263
# [2450]	train-rmse:0.02834	eval-rmse:0.03255
# [2500]	train-rmse:0.02818	eval-rmse:0.03246
# [2550]	train-rmse:0.02802	eval-rmse:0.03236
# [2600]	train-rmse:0.02786	eval-rmse:0.03227
# [2650]	train-rmse:0.02766	eval-rmse:0.03214
# [2700]	train-rmse:0.02748	eval-rmse:0.03201
# [2750]	train-rmse:0.02732	eval-rmse:0.03191
# [2800]	train-rmse:0.02712	eval-rmse:0.03178
# [2850]	train-rmse:0.02698	eval-rmse:0.03171
# [2900]	train-rmse:0.02689	eval-rmse:0.03164
# [2950]	train-rmse:0.02674	eval-rmse:0.03155
# [3000]	train-rmse:0.02658	eval-rmse:0.03145
# [3050]	train-rmse:0.02642	eval-rmse:0.03136
# [3100]	train-rmse:0.02628	eval-rmse:0.03127
# [3150]	train-rmse:0.02615	eval-rmse:0.03119
# [3200]	train-rmse:0.02604	eval-rmse:0.03115
# [3250]	train-rmse:0.02594	eval-rmse:0.03111
# [3300]	train-rmse:0.02582	eval-rmse:0.03108
# [3350]	train-rmse:0.02572	eval-rmse:0.03106
# [3400]	train-rmse:0.02561	eval-rmse:0.03103
# [3450]	train-rmse:0.02549	eval-rmse:0.03100
# [3500]	train-rmse:0.02540	eval-rmse:0.03097
# [3550]	train-rmse:0.02529	eval-rmse:0.03093
# [3600]	train-rmse:0.02516	eval-rmse:0.03090
# [3650]	train-rmse:0.02504	eval-rmse:0.03085
# [3700]	train-rmse:0.02492	eval-rmse:0.03081
# [3750]	train-rmse:0.02481	eval-rmse:0.03077
# [3800]	train-rmse:0.02470	eval-rmse:0.03071
# [3850]	train-rmse:0.02460	eval-rmse:0.03066
# [3900]	train-rmse:0.02450	eval-rmse:0.03061
# [3950]	train-rmse:0.02442	eval-rmse:0.03056
# [3999]	train-rmse:0.02434	eval-rmse:0.03054
# [0]	train-rmse:0.11543	eval-rmse:0.11390
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:39:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.07384	eval-rmse:0.07269
# [100]	train-rmse:0.04999	eval-rmse:0.04938
# [150]	train-rmse:0.03695	eval-rmse:0.03680
# [200]	train-rmse:0.03013	eval-rmse:0.03030
# [250]	train-rmse:0.02660	eval-rmse:0.02701
# [300]	train-rmse:0.02462	eval-rmse:0.02521
# [350]	train-rmse:0.02327	eval-rmse:0.02406
# [400]	train-rmse:0.02227	eval-rmse:0.02316
# [450]	train-rmse:0.02155	eval-rmse:0.02252
# [500]	train-rmse:0.02089	eval-rmse:0.02193
# [550]	train-rmse:0.02031	eval-rmse:0.02145
# [600]	train-rmse:0.01974	eval-rmse:0.02092
# [650]	train-rmse:0.01928	eval-rmse:0.02049
# [700]	train-rmse:0.01887	eval-rmse:0.02011
# [750]	train-rmse:0.01855	eval-rmse:0.01984
# [800]	train-rmse:0.01827	eval-rmse:0.01963
# [850]	train-rmse:0.01806	eval-rmse:0.01948
# [900]	train-rmse:0.01787	eval-rmse:0.01934
# [950]	train-rmse:0.01772	eval-rmse:0.01925
# [1000]	train-rmse:0.01758	eval-rmse:0.01917
# [1050]	train-rmse:0.01743	eval-rmse:0.01909
# [1100]	train-rmse:0.01729	eval-rmse:0.01901
# [1150]	train-rmse:0.01716	eval-rmse:0.01895
# [1200]	train-rmse:0.01701	eval-rmse:0.01886
# [1250]	train-rmse:0.01686	eval-rmse:0.01877
# [1300]	train-rmse:0.01672	eval-rmse:0.01869
# [1350]	train-rmse:0.01659	eval-rmse:0.01863
# [1400]	train-rmse:0.01647	eval-rmse:0.01862
# [1450]	train-rmse:0.01636	eval-rmse:0.01858
# [1500]	train-rmse:0.01624	eval-rmse:0.01851
# [1550]	train-rmse:0.01611	eval-rmse:0.01844
# [1600]	train-rmse:0.01599	eval-rmse:0.01835
# [1650]	train-rmse:0.01589	eval-rmse:0.01828
# [1700]	train-rmse:0.01581	eval-rmse:0.01824
# [1750]	train-rmse:0.01570	eval-rmse:0.01818
# [1800]	train-rmse:0.01562	eval-rmse:0.01816
# [1850]	train-rmse:0.01554	eval-rmse:0.01813
# [1900]	train-rmse:0.01545	eval-rmse:0.01808
# [1950]	train-rmse:0.01536	eval-rmse:0.01803
# [2000]	train-rmse:0.01528	eval-rmse:0.01799
# [2050]	train-rmse:0.01519	eval-rmse:0.01794
# [2100]	train-rmse:0.01511	eval-rmse:0.01790
# [2150]	train-rmse:0.01502	eval-rmse:0.01786
# [2200]	train-rmse:0.01494	eval-rmse:0.01780
# [2250]	train-rmse:0.01486	eval-rmse:0.01776
# [2300]	train-rmse:0.01478	eval-rmse:0.01772
# [2350]	train-rmse:0.01472	eval-rmse:0.01769
# [2400]	train-rmse:0.01467	eval-rmse:0.01767
# [2450]	train-rmse:0.01461	eval-rmse:0.01765
# [2500]	train-rmse:0.01456	eval-rmse:0.01763
# [2550]	train-rmse:0.01449	eval-rmse:0.01761
# [2600]	train-rmse:0.01441	eval-rmse:0.01757
# [2650]	train-rmse:0.01435	eval-rmse:0.01754
# [2700]	train-rmse:0.01428	eval-rmse:0.01750
# [2750]	train-rmse:0.01421	eval-rmse:0.01746
# [2800]	train-rmse:0.01416	eval-rmse:0.01744
# [2850]	train-rmse:0.01410	eval-rmse:0.01742
# [2900]	train-rmse:0.01404	eval-rmse:0.01739
# [2950]	train-rmse:0.01398	eval-rmse:0.01736
# [3000]	train-rmse:0.01391	eval-rmse:0.01733
# [3050]	train-rmse:0.01384	eval-rmse:0.01729
# [3100]	train-rmse:0.01379	eval-rmse:0.01726
# [3150]	train-rmse:0.01374	eval-rmse:0.01724
# [3200]	train-rmse:0.01365	eval-rmse:0.01719
# [3250]	train-rmse:0.01358	eval-rmse:0.01715
# [3300]	train-rmse:0.01354	eval-rmse:0.01713
# [3350]	train-rmse:0.01348	eval-rmse:0.01711
# [3400]	train-rmse:0.01343	eval-rmse:0.01708
# [3450]	train-rmse:0.01338	eval-rmse:0.01705
# [3500]	train-rmse:0.01333	eval-rmse:0.01702
# [3550]	train-rmse:0.01327	eval-rmse:0.01699
# [3600]	train-rmse:0.01321	eval-rmse:0.01695
# [3650]	train-rmse:0.01315	eval-rmse:0.01693
# [3700]	train-rmse:0.01310	eval-rmse:0.01690
# [3750]	train-rmse:0.01306	eval-rmse:0.01688
# [3800]	train-rmse:0.01300	eval-rmse:0.01685
# [3850]	train-rmse:0.01294	eval-rmse:0.01682
# [3900]	train-rmse:0.01288	eval-rmse:0.01680
# [3950]	train-rmse:0.01284	eval-rmse:0.01679
# [3999]	train-rmse:0.01276	eval-rmse:0.01674
# [0]	train-rmse:0.15315	eval-rmse:0.15413
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:39:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.09915	eval-rmse:0.09992
# [100]	train-rmse:0.06850	eval-rmse:0.06916
# [150]	train-rmse:0.05179	eval-rmse:0.05247
# [200]	train-rmse:0.04274	eval-rmse:0.04347
# [250]	train-rmse:0.03783	eval-rmse:0.03859
# [300]	train-rmse:0.03470	eval-rmse:0.03550
# [350]	train-rmse:0.03275	eval-rmse:0.03358
# [400]	train-rmse:0.03138	eval-rmse:0.03230
# [450]	train-rmse:0.03049	eval-rmse:0.03148
# [500]	train-rmse:0.02982	eval-rmse:0.03088
# [550]	train-rmse:0.02919	eval-rmse:0.03040
# [600]	train-rmse:0.02876	eval-rmse:0.03012
# [650]	train-rmse:0.02829	eval-rmse:0.02978
# [700]	train-rmse:0.02774	eval-rmse:0.02939
# [750]	train-rmse:0.02731	eval-rmse:0.02910
# [800]	train-rmse:0.02690	eval-rmse:0.02879
# [850]	train-rmse:0.02658	eval-rmse:0.02855
# [900]	train-rmse:0.02629	eval-rmse:0.02836
# [950]	train-rmse:0.02606	eval-rmse:0.02824
# [1000]	train-rmse:0.02585	eval-rmse:0.02811
# [1050]	train-rmse:0.02565	eval-rmse:0.02800
# [1100]	train-rmse:0.02549	eval-rmse:0.02791
# [1150]	train-rmse:0.02533	eval-rmse:0.02783
# [1200]	train-rmse:0.02514	eval-rmse:0.02771
# [1250]	train-rmse:0.02498	eval-rmse:0.02761
# [1300]	train-rmse:0.02476	eval-rmse:0.02747
# [1350]	train-rmse:0.02454	eval-rmse:0.02732
# [1400]	train-rmse:0.02435	eval-rmse:0.02721
# [1450]	train-rmse:0.02418	eval-rmse:0.02711
# [1500]	train-rmse:0.02402	eval-rmse:0.02701
# [1550]	train-rmse:0.02385	eval-rmse:0.02691
# [1600]	train-rmse:0.02370	eval-rmse:0.02682
# [1650]	train-rmse:0.02356	eval-rmse:0.02674
# [1700]	train-rmse:0.02339	eval-rmse:0.02665
# [1750]	train-rmse:0.02323	eval-rmse:0.02658
# [1800]	train-rmse:0.02307	eval-rmse:0.02649
# [1850]	train-rmse:0.02295	eval-rmse:0.02644
# [1900]	train-rmse:0.02283	eval-rmse:0.02639
# [1950]	train-rmse:0.02270	eval-rmse:0.02632
# [2000]	train-rmse:0.02257	eval-rmse:0.02627
# [2050]	train-rmse:0.02245	eval-rmse:0.02621
# [2100]	train-rmse:0.02231	eval-rmse:0.02614
# [2150]	train-rmse:0.02218	eval-rmse:0.02607
# [2200]	train-rmse:0.02207	eval-rmse:0.02600
# [2250]	train-rmse:0.02199	eval-rmse:0.02597
# [2300]	train-rmse:0.02188	eval-rmse:0.02593
# [2350]	train-rmse:0.02174	eval-rmse:0.02586
# [2400]	train-rmse:0.02163	eval-rmse:0.02581
# [2450]	train-rmse:0.02152	eval-rmse:0.02575
# [2500]	train-rmse:0.02139	eval-rmse:0.02567
# [2550]	train-rmse:0.02129	eval-rmse:0.02561
# [2600]	train-rmse:0.02120	eval-rmse:0.02555
# [2650]	train-rmse:0.02111	eval-rmse:0.02551
# [2700]	train-rmse:0.02103	eval-rmse:0.02547
# [2750]	train-rmse:0.02094	eval-rmse:0.02543
# [2800]	train-rmse:0.02084	eval-rmse:0.02537
# [2850]	train-rmse:0.02074	eval-rmse:0.02533
# [2900]	train-rmse:0.02063	eval-rmse:0.02528
# [2950]	train-rmse:0.02053	eval-rmse:0.02523
# [3000]	train-rmse:0.02046	eval-rmse:0.02520
# [3050]	train-rmse:0.02038	eval-rmse:0.02517
# [3100]	train-rmse:0.02028	eval-rmse:0.02511
# [3150]	train-rmse:0.02018	eval-rmse:0.02503
# [3200]	train-rmse:0.02009	eval-rmse:0.02499
# [3250]	train-rmse:0.01998	eval-rmse:0.02493
# [3300]	train-rmse:0.01989	eval-rmse:0.02489
# [3350]	train-rmse:0.01982	eval-rmse:0.02486
# [3400]	train-rmse:0.01975	eval-rmse:0.02482
# [3450]	train-rmse:0.01967	eval-rmse:0.02480
# [3500]	train-rmse:0.01960	eval-rmse:0.02477
# [3550]	train-rmse:0.01954	eval-rmse:0.02474
# [3600]	train-rmse:0.01946	eval-rmse:0.02471
# [3650]	train-rmse:0.01939	eval-rmse:0.02468
# [3700]	train-rmse:0.01930	eval-rmse:0.02464
# [3750]	train-rmse:0.01924	eval-rmse:0.02462
# [3800]	train-rmse:0.01918	eval-rmse:0.02461
# [3850]	train-rmse:0.01908	eval-rmse:0.02457
# [3900]	train-rmse:0.01898	eval-rmse:0.02451
# [3950]	train-rmse:0.01887	eval-rmse:0.02445
# [3999]	train-rmse:0.01878	eval-rmse:0.02440
# [0]	train-rmse:0.09365	eval-rmse:0.09279
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:40:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.05961	eval-rmse:0.05918
# [100]	train-rmse:0.03966	eval-rmse:0.03967
# [150]	train-rmse:0.02828	eval-rmse:0.02865
# [200]	train-rmse:0.02176	eval-rmse:0.02241
# [250]	train-rmse:0.01798	eval-rmse:0.01878
# [300]	train-rmse:0.01562	eval-rmse:0.01642
# [350]	train-rmse:0.01404	eval-rmse:0.01486
# [400]	train-rmse:0.01275	eval-rmse:0.01355
# [450]	train-rmse:0.01152	eval-rmse:0.01232
# [500]	train-rmse:0.01052	eval-rmse:0.01135
# [550]	train-rmse:0.00975	eval-rmse:0.01060
# [600]	train-rmse:0.00919	eval-rmse:0.01003
# [650]	train-rmse:0.00871	eval-rmse:0.00956
# [700]	train-rmse:0.00827	eval-rmse:0.00914
# [750]	train-rmse:0.00783	eval-rmse:0.00873
# [800]	train-rmse:0.00752	eval-rmse:0.00843
# [850]	train-rmse:0.00733	eval-rmse:0.00823
# [900]	train-rmse:0.00716	eval-rmse:0.00806
# [950]	train-rmse:0.00699	eval-rmse:0.00790
# [1000]	train-rmse:0.00683	eval-rmse:0.00774
# [1050]	train-rmse:0.00671	eval-rmse:0.00762
# [1100]	train-rmse:0.00660	eval-rmse:0.00750
# [1150]	train-rmse:0.00652	eval-rmse:0.00743
# [1200]	train-rmse:0.00643	eval-rmse:0.00734
# [1250]	train-rmse:0.00636	eval-rmse:0.00728
# [1300]	train-rmse:0.00630	eval-rmse:0.00723
# [1350]	train-rmse:0.00623	eval-rmse:0.00715
# [1400]	train-rmse:0.00616	eval-rmse:0.00710
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:723: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:40:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.06394	eval-rmse:0.06942
# [100]	train-rmse:0.04722	eval-rmse:0.05186
# [150]	train-rmse:0.03835	eval-rmse:0.04252
# [200]	train-rmse:0.03365	eval-rmse:0.03765
# [250]	train-rmse:0.03094	eval-rmse:0.03488
# [300]	train-rmse:0.02919	eval-rmse:0.03314
# [350]	train-rmse:0.02788	eval-rmse:0.03172
# [400]	train-rmse:0.02678	eval-rmse:0.03058
# [450]	train-rmse:0.02592	eval-rmse:0.02966
# [500]	train-rmse:0.02528	eval-rmse:0.02896
# [550]	train-rmse:0.02485	eval-rmse:0.02851
# [600]	train-rmse:0.02438	eval-rmse:0.02801
# [650]	train-rmse:0.02396	eval-rmse:0.02757
# [700]	train-rmse:0.02357	eval-rmse:0.02716
# [750]	train-rmse:0.02321	eval-rmse:0.02682
# [800]	train-rmse:0.02288	eval-rmse:0.02649
# [850]	train-rmse:0.02257	eval-rmse:0.02616
# [900]	train-rmse:0.02225	eval-rmse:0.02584
# [950]	train-rmse:0.02199	eval-rmse:0.02557
# [1000]	train-rmse:0.02171	eval-rmse:0.02530
# [1050]	train-rmse:0.02148	eval-rmse:0.02507
# [1100]	train-rmse:0.02127	eval-rmse:0.02486
# [1150]	train-rmse:0.02109	eval-rmse:0.02470
# [1200]	train-rmse:0.02090	eval-rmse:0.02453
# [1250]	train-rmse:0.02075	eval-rmse:0.02440
# [1300]	train-rmse:0.02060	eval-rmse:0.02426
# [1350]	train-rmse:0.02043	eval-rmse:0.02410
# [1400]	train-rmse:0.02029	eval-rmse:0.02397
# [1450]	train-rmse:0.02018	eval-rmse:0.02388
# [1500]	train-rmse:0.02007	eval-rmse:0.02379
# [1550]	train-rmse:0.01996	eval-rmse:0.02371
# [1600]	train-rmse:0.01984	eval-rmse:0.02362
# [1650]	train-rmse:0.01975	eval-rmse:0.02356
# [1700]	train-rmse:0.01964	eval-rmse:0.02348
# [1750]	train-rmse:0.01953	eval-rmse:0.02339
# [1800]	train-rmse:0.01941	eval-rmse:0.02330
# [1850]	train-rmse:0.01931	eval-rmse:0.02325
# [1900]	train-rmse:0.01921	eval-rmse:0.02317
# [1950]	train-rmse:0.01908	eval-rmse:0.02308
# [2000]	train-rmse:0.01896	eval-rmse:0.02300
# [2050]	train-rmse:0.01887	eval-rmse:0.02293
# [2100]	train-rmse:0.01878	eval-rmse:0.02287
# [2150]	train-rmse:0.01869	eval-rmse:0.02280
# [2200]	train-rmse:0.01861	eval-rmse:0.02274
# [2250]	train-rmse:0.01850	eval-rmse:0.02267
# [2300]	train-rmse:0.01842	eval-rmse:0.02262
# [2350]	train-rmse:0.01833	eval-rmse:0.02257
# [2400]	train-rmse:0.01826	eval-rmse:0.02252
# [2450]	train-rmse:0.01818	eval-rmse:0.02247
# [2500]	train-rmse:0.01808	eval-rmse:0.02241
# [2550]	train-rmse:0.01799	eval-rmse:0.02235
# [2600]	train-rmse:0.01792	eval-rmse:0.02231
# [2650]	train-rmse:0.01784	eval-rmse:0.02227
# [2700]	train-rmse:0.01778	eval-rmse:0.02224
# [2750]	train-rmse:0.01771	eval-rmse:0.02221
# [2800]	train-rmse:0.01764	eval-rmse:0.02218
# [2850]	train-rmse:0.01757	eval-rmse:0.02213
# [2900]	train-rmse:0.01751	eval-rmse:0.02209
# [2950]	train-rmse:0.01742	eval-rmse:0.02204
# [3000]	train-rmse:0.01736	eval-rmse:0.02201
# [3050]	train-rmse:0.01729	eval-rmse:0.02196
# [3100]	train-rmse:0.01723	eval-rmse:0.02193
# [3150]	train-rmse:0.01715	eval-rmse:0.02188
# [3200]	train-rmse:0.01708	eval-rmse:0.02183
# [3250]	train-rmse:0.01701	eval-rmse:0.02180
# [3300]	train-rmse:0.01695	eval-rmse:0.02177
# [3350]	train-rmse:0.01686	eval-rmse:0.02172
# [3400]	train-rmse:0.01680	eval-rmse:0.02168
# [3450]	train-rmse:0.01671	eval-rmse:0.02162
# [3500]	train-rmse:0.01662	eval-rmse:0.02157
# [3550]	train-rmse:0.01655	eval-rmse:0.02152
# [3600]	train-rmse:0.01649	eval-rmse:0.02149
# [3650]	train-rmse:0.01642	eval-rmse:0.02146
# [3700]	train-rmse:0.01635	eval-rmse:0.02141
# [3750]	train-rmse:0.01630	eval-rmse:0.02138
# [3800]	train-rmse:0.01623	eval-rmse:0.02134
# [3850]	train-rmse:0.01615	eval-rmse:0.02131
# [3900]	train-rmse:0.01609	eval-rmse:0.02129
# [3950]	train-rmse:0.01603	eval-rmse:0.02125
# [3999]	train-rmse:0.01596	eval-rmse:0.02120
# [0]	train-rmse:0.11548	eval-rmse:0.11830
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:41:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.07233	eval-rmse:0.07385
# [100]	train-rmse:0.04733	eval-rmse:0.04808
# [150]	train-rmse:0.03359	eval-rmse:0.03391
# [200]	train-rmse:0.02656	eval-rmse:0.02670
# [250]	train-rmse:0.02310	eval-rmse:0.02325
# [300]	train-rmse:0.02139	eval-rmse:0.02161
# [350]	train-rmse:0.02039	eval-rmse:0.02075
# [400]	train-rmse:0.01977	eval-rmse:0.02023
# [450]	train-rmse:0.01929	eval-rmse:0.01982
# [500]	train-rmse:0.01888	eval-rmse:0.01953
# [550]	train-rmse:0.01847	eval-rmse:0.01923
# [600]	train-rmse:0.01810	eval-rmse:0.01898
# [650]	train-rmse:0.01779	eval-rmse:0.01876
# [700]	train-rmse:0.01749	eval-rmse:0.01856
# [750]	train-rmse:0.01720	eval-rmse:0.01838
# [800]	train-rmse:0.01693	eval-rmse:0.01821
# [850]	train-rmse:0.01670	eval-rmse:0.01807
# [900]	train-rmse:0.01646	eval-rmse:0.01794
# [950]	train-rmse:0.01626	eval-rmse:0.01783
# [1000]	train-rmse:0.01607	eval-rmse:0.01771
# [1050]	train-rmse:0.01591	eval-rmse:0.01762
# [1100]	train-rmse:0.01577	eval-rmse:0.01753
# [1150]	train-rmse:0.01563	eval-rmse:0.01744
# [1200]	train-rmse:0.01550	eval-rmse:0.01736
# [1250]	train-rmse:0.01536	eval-rmse:0.01729
# [1300]	train-rmse:0.01523	eval-rmse:0.01722
# [1350]	train-rmse:0.01511	eval-rmse:0.01717
# [1400]	train-rmse:0.01500	eval-rmse:0.01712
# [1450]	train-rmse:0.01489	eval-rmse:0.01708
# [1500]	train-rmse:0.01481	eval-rmse:0.01704
# [1550]	train-rmse:0.01470	eval-rmse:0.01699
# [1600]	train-rmse:0.01460	eval-rmse:0.01694
# [1650]	train-rmse:0.01450	eval-rmse:0.01691
# [1700]	train-rmse:0.01441	eval-rmse:0.01686
# [1750]	train-rmse:0.01432	eval-rmse:0.01683
# [1800]	train-rmse:0.01422	eval-rmse:0.01679
# [1850]	train-rmse:0.01415	eval-rmse:0.01677
# [1900]	train-rmse:0.01407	eval-rmse:0.01675
# [1950]	train-rmse:0.01398	eval-rmse:0.01672
# [2000]	train-rmse:0.01390	eval-rmse:0.01668
# [2050]	train-rmse:0.01382	eval-rmse:0.01665
# [2100]	train-rmse:0.01376	eval-rmse:0.01663
# [2150]	train-rmse:0.01370	eval-rmse:0.01661
# [2200]	train-rmse:0.01363	eval-rmse:0.01659
# [2250]	train-rmse:0.01356	eval-rmse:0.01656
# [2300]	train-rmse:0.01349	eval-rmse:0.01653
# [2350]	train-rmse:0.01343	eval-rmse:0.01650
# [2400]	train-rmse:0.01338	eval-rmse:0.01649
# [2450]	train-rmse:0.01332	eval-rmse:0.01647
# [2500]	train-rmse:0.01325	eval-rmse:0.01645
# [2550]	train-rmse:0.01318	eval-rmse:0.01642
# [2600]	train-rmse:0.01313	eval-rmse:0.01640
# [2650]	train-rmse:0.01308	eval-rmse:0.01639
# [2700]	train-rmse:0.01300	eval-rmse:0.01637
# [2750]	train-rmse:0.01294	eval-rmse:0.01634
# [2800]	train-rmse:0.01289	eval-rmse:0.01632
# [2850]	train-rmse:0.01283	eval-rmse:0.01631
# [2900]	train-rmse:0.01277	eval-rmse:0.01629
# [2950]	train-rmse:0.01272	eval-rmse:0.01628
# [3000]	train-rmse:0.01266	eval-rmse:0.01626
# [3050]	train-rmse:0.01261	eval-rmse:0.01625
# [3100]	train-rmse:0.01256	eval-rmse:0.01624
# [3150]	train-rmse:0.01250	eval-rmse:0.01623
# [3200]	train-rmse:0.01246	eval-rmse:0.01621
# [3250]	train-rmse:0.01240	eval-rmse:0.01619
# [3300]	train-rmse:0.01235	eval-rmse:0.01617
# [3350]	train-rmse:0.01230	eval-rmse:0.01615
# [3400]	train-rmse:0.01226	eval-rmse:0.01613
# [3450]	train-rmse:0.01221	eval-rmse:0.01612
# [3500]	train-rmse:0.01217	eval-rmse:0.01610
# [3550]	train-rmse:0.01212	eval-rmse:0.01609
# [3600]	train-rmse:0.01208	eval-rmse:0.01608
# [3635]	train-rmse:0.01205	eval-rmse:0.01609
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:41:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	train-rmse:0.09863	eval-rmse:0.10046
# [50]	train-rmse:0.07433	eval-rmse:0.07648
# [100]	train-rmse:0.06261	eval-rmse:0.06521
# [150]	train-rmse:0.05713	eval-rmse:0.06017
# [200]	train-rmse:0.05420	eval-rmse:0.05760
# [250]	train-rmse:0.05233	eval-rmse:0.05581
# [300]	train-rmse:0.05057	eval-rmse:0.05397
# [350]	train-rmse:0.04912	eval-rmse:0.05253
# [400]	train-rmse:0.04798	eval-rmse:0.05146
# [450]	train-rmse:0.04717	eval-rmse:0.05073
# [500]	train-rmse:0.04634	eval-rmse:0.04991
# [550]	train-rmse:0.04555	eval-rmse:0.04914
# [600]	train-rmse:0.04479	eval-rmse:0.04836
# [650]	train-rmse:0.04411	eval-rmse:0.04765
# [700]	train-rmse:0.04353	eval-rmse:0.04706
# [750]	train-rmse:0.04297	eval-rmse:0.04655
# [800]	train-rmse:0.04239	eval-rmse:0.04602
# [850]	train-rmse:0.04183	eval-rmse:0.04546
# [900]	train-rmse:0.04135	eval-rmse:0.04503
# [950]	train-rmse:0.04091	eval-rmse:0.04467
# [1000]	train-rmse:0.04047	eval-rmse:0.04430
# [1050]	train-rmse:0.04011	eval-rmse:0.04401
# [1100]	train-rmse:0.03976	eval-rmse:0.04376
# [1150]	train-rmse:0.03944	eval-rmse:0.04353
# [1200]	train-rmse:0.03915	eval-rmse:0.04326
# [1250]	train-rmse:0.03885	eval-rmse:0.04302
# [1300]	train-rmse:0.03858	eval-rmse:0.04280
# [1350]	train-rmse:0.03830	eval-rmse:0.04258
# [1400]	train-rmse:0.03805	eval-rmse:0.04238
# [1450]	train-rmse:0.03776	eval-rmse:0.04215
# [1500]	train-rmse:0.03748	eval-rmse:0.04191
# [1550]	train-rmse:0.03721	eval-rmse:0.04166
# [1600]	train-rmse:0.03697	eval-rmse:0.04146
# [1650]	train-rmse:0.03677	eval-rmse:0.04131
# [1700]	train-rmse:0.03657	eval-rmse:0.04117
# [1750]	train-rmse:0.03642	eval-rmse:0.04109
# [1800]	train-rmse:0.03628	eval-rmse:0.04101
# [1850]	train-rmse:0.03614	eval-rmse:0.04092
# [1900]	train-rmse:0.03598	eval-rmse:0.04083
# [1950]	train-rmse:0.03579	eval-rmse:0.04069
# [2000]	train-rmse:0.03560	eval-rmse:0.04056
# [2050]	train-rmse:0.03541	eval-rmse:0.04044
# [2100]	train-rmse:0.03525	eval-rmse:0.04034
# [2150]	train-rmse:0.03506	eval-rmse:0.04020
# [2200]	train-rmse:0.03487	eval-rmse:0.04010
# [2250]	train-rmse:0.03467	eval-rmse:0.03997
# [2300]	train-rmse:0.03447	eval-rmse:0.03985
# [2350]	train-rmse:0.03429	eval-rmse:0.03973
# [2400]	train-rmse:0.03415	eval-rmse:0.03964
# [2450]	train-rmse:0.03398	eval-rmse:0.03952
# [2500]	train-rmse:0.03379	eval-rmse:0.03941
# [2550]	train-rmse:0.03365	eval-rmse:0.03934
# [2600]	train-rmse:0.03351	eval-rmse:0.03924
# [2650]	train-rmse:0.03336	eval-rmse:0.03915
# [2700]	train-rmse:0.03313	eval-rmse:0.03900
# [2750]	train-rmse:0.03293	eval-rmse:0.03885
# [2800]	train-rmse:0.03278	eval-rmse:0.03873
# [2850]	train-rmse:0.03269	eval-rmse:0.03869
# [2900]	train-rmse:0.03256	eval-rmse:0.03862
# [2950]	train-rmse:0.03245	eval-rmse:0.03854
# [3000]	train-rmse:0.03237	eval-rmse:0.03851
# [3050]	train-rmse:0.03227	eval-rmse:0.03845
# [3100]	train-rmse:0.03214	eval-rmse:0.03838
# [3150]	train-rmse:0.03205	eval-rmse:0.03834
# [3200]	train-rmse:0.03194	eval-rmse:0.03828
# [3250]	train-rmse:0.03182	eval-rmse:0.03819
# [3300]	train-rmse:0.03170	eval-rmse:0.03814
# [3350]	train-rmse:0.03155	eval-rmse:0.03804
# [3400]	train-rmse:0.03145	eval-rmse:0.03800
# [3450]	train-rmse:0.03133	eval-rmse:0.03794
# [3500]	train-rmse:0.03127	eval-rmse:0.03793
# [3550]	train-rmse:0.03114	eval-rmse:0.03787
# [3600]	train-rmse:0.03101	eval-rmse:0.03782
# [3650]	train-rmse:0.03093	eval-rmse:0.03780
# [3700]	train-rmse:0.03086	eval-rmse:0.03778
# [3750]	train-rmse:0.03076	eval-rmse:0.03775
# [3800]	train-rmse:0.03061	eval-rmse:0.03768
# [3850]	train-rmse:0.03050	eval-rmse:0.03763
# [3900]	train-rmse:0.03035	eval-rmse:0.03756
# [3950]	train-rmse:0.03022	eval-rmse:0.03750
# [3999]	train-rmse:0.03013	eval-rmse:0.03748
# [0]	train-rmse:0.15664	eval-rmse:0.15831
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:41:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.10801	eval-rmse:0.10934
# [100]	train-rmse:0.08206	eval-rmse:0.08347
# [150]	train-rmse:0.06901	eval-rmse:0.07080
# [200]	train-rmse:0.06101	eval-rmse:0.06323
# [250]	train-rmse:0.05544	eval-rmse:0.05816
# [300]	train-rmse:0.05106	eval-rmse:0.05398
# [350]	train-rmse:0.04769	eval-rmse:0.05055
# [400]	train-rmse:0.04488	eval-rmse:0.04767
# [450]	train-rmse:0.04272	eval-rmse:0.04551
# [500]	train-rmse:0.04091	eval-rmse:0.04366
# [550]	train-rmse:0.03934	eval-rmse:0.04209
# [600]	train-rmse:0.03810	eval-rmse:0.04095
# [650]	train-rmse:0.03717	eval-rmse:0.04011
# [700]	train-rmse:0.03642	eval-rmse:0.03943
# [750]	train-rmse:0.03573	eval-rmse:0.03879
# [800]	train-rmse:0.03521	eval-rmse:0.03834
# [850]	train-rmse:0.03477	eval-rmse:0.03798
# [900]	train-rmse:0.03433	eval-rmse:0.03763
# [950]	train-rmse:0.03397	eval-rmse:0.03737
# [1000]	train-rmse:0.03364	eval-rmse:0.03712
# [1050]	train-rmse:0.03337	eval-rmse:0.03693
# [1100]	train-rmse:0.03310	eval-rmse:0.03674
# [1150]	train-rmse:0.03287	eval-rmse:0.03658
# [1200]	train-rmse:0.03265	eval-rmse:0.03643
# [1250]	train-rmse:0.03241	eval-rmse:0.03627
# [1300]	train-rmse:0.03215	eval-rmse:0.03611
# [1350]	train-rmse:0.03191	eval-rmse:0.03596
# [1400]	train-rmse:0.03164	eval-rmse:0.03579
# [1450]	train-rmse:0.03140	eval-rmse:0.03563
# [1500]	train-rmse:0.03117	eval-rmse:0.03550
# [1550]	train-rmse:0.03097	eval-rmse:0.03538
# [1600]	train-rmse:0.03079	eval-rmse:0.03526
# [1650]	train-rmse:0.03058	eval-rmse:0.03512
# [1700]	train-rmse:0.03038	eval-rmse:0.03498
# [1750]	train-rmse:0.03020	eval-rmse:0.03486
# [1800]	train-rmse:0.03005	eval-rmse:0.03476
# [1850]	train-rmse:0.02988	eval-rmse:0.03467
# [1900]	train-rmse:0.02973	eval-rmse:0.03458
# [1950]	train-rmse:0.02957	eval-rmse:0.03448
# [2000]	train-rmse:0.02941	eval-rmse:0.03437
# [2050]	train-rmse:0.02927	eval-rmse:0.03429
# [2100]	train-rmse:0.02914	eval-rmse:0.03423
# [2150]	train-rmse:0.02898	eval-rmse:0.03414
# [2200]	train-rmse:0.02882	eval-rmse:0.03406
# [2250]	train-rmse:0.02865	eval-rmse:0.03399
# [2300]	train-rmse:0.02843	eval-rmse:0.03391
# [2350]	train-rmse:0.02821	eval-rmse:0.03381
# [2400]	train-rmse:0.02801	eval-rmse:0.03371
# [2450]	train-rmse:0.02785	eval-rmse:0.03361
# [2500]	train-rmse:0.02768	eval-rmse:0.03351
# [2550]	train-rmse:0.02752	eval-rmse:0.03342
# [2600]	train-rmse:0.02736	eval-rmse:0.03333
# [2650]	train-rmse:0.02721	eval-rmse:0.03325
# [2700]	train-rmse:0.02707	eval-rmse:0.03316
# [2750]	train-rmse:0.02695	eval-rmse:0.03311
# [2800]	train-rmse:0.02680	eval-rmse:0.03302
# [2850]	train-rmse:0.02664	eval-rmse:0.03296
# [2900]	train-rmse:0.02653	eval-rmse:0.03293
# [2950]	train-rmse:0.02640	eval-rmse:0.03288
# [3000]	train-rmse:0.02629	eval-rmse:0.03286
# [3050]	train-rmse:0.02620	eval-rmse:0.03283
# [3100]	train-rmse:0.02610	eval-rmse:0.03280
# [3150]	train-rmse:0.02597	eval-rmse:0.03274
# [3200]	train-rmse:0.02588	eval-rmse:0.03271
# [3250]	train-rmse:0.02578	eval-rmse:0.03265
# [3300]	train-rmse:0.02568	eval-rmse:0.03260
# [3350]	train-rmse:0.02557	eval-rmse:0.03255
# [3400]	train-rmse:0.02547	eval-rmse:0.03252
# [3450]	train-rmse:0.02536	eval-rmse:0.03248
# [3500]	train-rmse:0.02527	eval-rmse:0.03243
# [3550]	train-rmse:0.02518	eval-rmse:0.03239
# [3600]	train-rmse:0.02507	eval-rmse:0.03235
# [3650]	train-rmse:0.02495	eval-rmse:0.03231
# [3700]	train-rmse:0.02485	eval-rmse:0.03228
# [3750]	train-rmse:0.02470	eval-rmse:0.03219
# [3800]	train-rmse:0.02451	eval-rmse:0.03207
# [3850]	train-rmse:0.02441	eval-rmse:0.03203
# [3900]	train-rmse:0.02431	eval-rmse:0.03198
# [3950]	train-rmse:0.02420	eval-rmse:0.03192
# [3999]	train-rmse:0.02410	eval-rmse:0.03187
# [0]	train-rmse:0.11405	eval-rmse:0.12063
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:42:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.07292	eval-rmse:0.07786
# [100]	train-rmse:0.04934	eval-rmse:0.05352
# [150]	train-rmse:0.03639	eval-rmse:0.04009
# [200]	train-rmse:0.02960	eval-rmse:0.03307
# [250]	train-rmse:0.02605	eval-rmse:0.02939
# [300]	train-rmse:0.02414	eval-rmse:0.02740
# [350]	train-rmse:0.02294	eval-rmse:0.02615
# [400]	train-rmse:0.02198	eval-rmse:0.02515
# [450]	train-rmse:0.02128	eval-rmse:0.02441
# [500]	train-rmse:0.02065	eval-rmse:0.02376
# [550]	train-rmse:0.02014	eval-rmse:0.02319
# [600]	train-rmse:0.01963	eval-rmse:0.02258
# [650]	train-rmse:0.01925	eval-rmse:0.02217
# [700]	train-rmse:0.01889	eval-rmse:0.02180
# [750]	train-rmse:0.01865	eval-rmse:0.02153
# [800]	train-rmse:0.01838	eval-rmse:0.02124
# [850]	train-rmse:0.01814	eval-rmse:0.02099
# [900]	train-rmse:0.01797	eval-rmse:0.02084
# [950]	train-rmse:0.01777	eval-rmse:0.02064
# [1000]	train-rmse:0.01757	eval-rmse:0.02044
# [1050]	train-rmse:0.01741	eval-rmse:0.02026
# [1100]	train-rmse:0.01725	eval-rmse:0.02010
# [1150]	train-rmse:0.01711	eval-rmse:0.01998
# [1200]	train-rmse:0.01695	eval-rmse:0.01985
# [1250]	train-rmse:0.01677	eval-rmse:0.01970
# [1300]	train-rmse:0.01663	eval-rmse:0.01958
# [1350]	train-rmse:0.01649	eval-rmse:0.01947
# [1400]	train-rmse:0.01636	eval-rmse:0.01936
# [1450]	train-rmse:0.01624	eval-rmse:0.01927
# [1500]	train-rmse:0.01614	eval-rmse:0.01920
# [1550]	train-rmse:0.01604	eval-rmse:0.01913
# [1600]	train-rmse:0.01595	eval-rmse:0.01907
# [1650]	train-rmse:0.01585	eval-rmse:0.01899
# [1700]	train-rmse:0.01575	eval-rmse:0.01892
# [1750]	train-rmse:0.01564	eval-rmse:0.01885
# [1800]	train-rmse:0.01551	eval-rmse:0.01875
# [1850]	train-rmse:0.01541	eval-rmse:0.01870
# [1900]	train-rmse:0.01530	eval-rmse:0.01862
# [1950]	train-rmse:0.01521	eval-rmse:0.01856
# [2000]	train-rmse:0.01513	eval-rmse:0.01850
# [2050]	train-rmse:0.01505	eval-rmse:0.01845
# [2100]	train-rmse:0.01498	eval-rmse:0.01842
# [2150]	train-rmse:0.01488	eval-rmse:0.01835
# [2200]	train-rmse:0.01478	eval-rmse:0.01828
# [2250]	train-rmse:0.01468	eval-rmse:0.01820
# [2300]	train-rmse:0.01458	eval-rmse:0.01814
# [2350]	train-rmse:0.01450	eval-rmse:0.01809
# [2400]	train-rmse:0.01440	eval-rmse:0.01803
# [2450]	train-rmse:0.01432	eval-rmse:0.01798
# [2500]	train-rmse:0.01425	eval-rmse:0.01793
# [2550]	train-rmse:0.01417	eval-rmse:0.01788
# [2600]	train-rmse:0.01409	eval-rmse:0.01782
# [2650]	train-rmse:0.01402	eval-rmse:0.01779
# [2700]	train-rmse:0.01393	eval-rmse:0.01774
# [2750]	train-rmse:0.01389	eval-rmse:0.01772
# [2800]	train-rmse:0.01383	eval-rmse:0.01769
# [2850]	train-rmse:0.01375	eval-rmse:0.01763
# [2900]	train-rmse:0.01368	eval-rmse:0.01760
# [2950]	train-rmse:0.01362	eval-rmse:0.01756
# [3000]	train-rmse:0.01356	eval-rmse:0.01753
# [3050]	train-rmse:0.01351	eval-rmse:0.01750
# [3100]	train-rmse:0.01344	eval-rmse:0.01747
# [3150]	train-rmse:0.01335	eval-rmse:0.01741
# [3200]	train-rmse:0.01327	eval-rmse:0.01737
# [3250]	train-rmse:0.01320	eval-rmse:0.01733
# [3300]	train-rmse:0.01314	eval-rmse:0.01731
# [3350]	train-rmse:0.01309	eval-rmse:0.01729
# [3400]	train-rmse:0.01303	eval-rmse:0.01726
# [3450]	train-rmse:0.01299	eval-rmse:0.01724
# [3500]	train-rmse:0.01295	eval-rmse:0.01722
# [3550]	train-rmse:0.01292	eval-rmse:0.01721
# [3600]	train-rmse:0.01288	eval-rmse:0.01720
# [3650]	train-rmse:0.01285	eval-rmse:0.01719
# [3700]	train-rmse:0.01281	eval-rmse:0.01717
# [3750]	train-rmse:0.01274	eval-rmse:0.01714
# [3800]	train-rmse:0.01268	eval-rmse:0.01712
# [3850]	train-rmse:0.01264	eval-rmse:0.01710
# [3900]	train-rmse:0.01260	eval-rmse:0.01708
# [3950]	train-rmse:0.01257	eval-rmse:0.01707
# [3999]	train-rmse:0.01253	eval-rmse:0.01705
# [0]	train-rmse:0.15263	eval-rmse:0.15654
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:42:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.09877	eval-rmse:0.10111
# [100]	train-rmse:0.06821	eval-rmse:0.06960
# [150]	train-rmse:0.05161	eval-rmse:0.05273
# ...
# [1650]	train-rmse:0.03062	eval-rmse:0.03445
# [1700]	train-rmse:0.03042	eval-rmse:0.03433
# [1750]	train-rmse:0.03017	eval-rmse:0.03418
# [1800]	train-rmse:0.02999	eval-rmse:0.03407
# [1850]	train-rmse:0.02982	eval-rmse:0.03396
# [1900]	train-rmse:0.02966	eval-rmse:0.03386
# [1950]	train-rmse:0.02951	eval-rmse:0.03377
# [2000]	train-rmse:0.02936	eval-rmse:0.03368
# [2050]	train-rmse:0.02920	eval-rmse:0.03358
# [2100]	train-rmse:0.02905	eval-rmse:0.03347
# [2150]	train-rmse:0.02887	eval-rmse:0.03335
# [2200]	train-rmse:0.02874	eval-rmse:0.03327
# [2250]	train-rmse:0.02859	eval-rmse:0.03319
# [2300]	train-rmse:0.02846	eval-rmse:0.03313
# [2350]	train-rmse:0.02833	eval-rmse:0.03307
# [2400]	train-rmse:0.02819	eval-rmse:0.03303
# [2450]	train-rmse:0.02806	eval-rmse:0.03296
# [2500]	train-rmse:0.02794	eval-rmse:0.03291
# [2550]	train-rmse:0.02776	eval-rmse:0.03280
# [2600]	train-rmse:0.02765	eval-rmse:0.03275
# [2650]	train-rmse:0.02752	eval-rmse:0.03269
# [2700]	train-rmse:0.02736	eval-rmse:0.03262
# [2750]	train-rmse:0.02719	eval-rmse:0.03254
# [2800]	train-rmse:0.02703	eval-rmse:0.03249
# [2850]	train-rmse:0.02692	eval-rmse:0.03243
# [2900]	train-rmse:0.02680	eval-rmse:0.03237
# [2950]	train-rmse:0.02668	eval-rmse:0.03231
# [3000]	train-rmse:0.02657	eval-rmse:0.03226
# [3050]	train-rmse:0.02641	eval-rmse:0.03219
# [3100]	train-rmse:0.02625	eval-rmse:0.03212
# [3150]	train-rmse:0.02614	eval-rmse:0.03208
# [3200]	train-rmse:0.02596	eval-rmse:0.03197
# [3250]	train-rmse:0.02582	eval-rmse:0.03190
# [3300]	train-rmse:0.02573	eval-rmse:0.03188
# [3350]	train-rmse:0.02563	eval-rmse:0.03188
# [3400]	train-rmse:0.02553	eval-rmse:0.03185
# [3450]	train-rmse:0.02540	eval-rmse:0.03180
# [3500]	train-rmse:0.02530	eval-rmse:0.03177
# [3550]	train-rmse:0.02515	eval-rmse:0.03171
# [3600]	train-rmse:0.02505	eval-rmse:0.03166
# [3650]	train-rmse:0.02492	eval-rmse:0.03162
# [3700]	train-rmse:0.02480	eval-rmse:0.03155
# [3750]	train-rmse:0.02470	eval-rmse:0.03151
# [3800]	train-rmse:0.02458	eval-rmse:0.03148
# [3850]	train-rmse:0.02451	eval-rmse:0.03147
# [3900]	train-rmse:0.02440	eval-rmse:0.03142
# [3950]	train-rmse:0.02432	eval-rmse:0.03137
# [3999]	train-rmse:0.02423	eval-rmse:0.03134
# [0]	train-rmse:0.11557	eval-rmse:0.11126
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:51:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.07390	eval-rmse:0.07119
# [100]	train-rmse:0.05002	eval-rmse:0.04832
# [150]	train-rmse:0.03700	eval-rmse:0.03606
# [200]	train-rmse:0.03015	eval-rmse:0.02980
# [250]	train-rmse:0.02652	eval-rmse:0.02660
# [300]	train-rmse:0.02451	eval-rmse:0.02487
# [350]	train-rmse:0.02312	eval-rmse:0.02360
# [400]	train-rmse:0.02214	eval-rmse:0.02274
# [450]	train-rmse:0.02140	eval-rmse:0.02212
# [500]	train-rmse:0.02071	eval-rmse:0.02154
# [550]	train-rmse:0.01994	eval-rmse:0.02087
# [600]	train-rmse:0.01943	eval-rmse:0.02043
# [650]	train-rmse:0.01902	eval-rmse:0.02009
# [700]	train-rmse:0.01870	eval-rmse:0.01982
# [750]	train-rmse:0.01843	eval-rmse:0.01960
# [800]	train-rmse:0.01818	eval-rmse:0.01941
# [850]	train-rmse:0.01799	eval-rmse:0.01927
# [900]	train-rmse:0.01777	eval-rmse:0.01911
# [950]	train-rmse:0.01754	eval-rmse:0.01895
# [1000]	train-rmse:0.01735	eval-rmse:0.01882
# [1050]	train-rmse:0.01720	eval-rmse:0.01872
# [1100]	train-rmse:0.01703	eval-rmse:0.01861
# [1150]	train-rmse:0.01685	eval-rmse:0.01850
# [1200]	train-rmse:0.01668	eval-rmse:0.01837
# [1250]	train-rmse:0.01651	eval-rmse:0.01825
# [1300]	train-rmse:0.01636	eval-rmse:0.01816
# [1350]	train-rmse:0.01624	eval-rmse:0.01809
# [1400]	train-rmse:0.01611	eval-rmse:0.01802
# [1450]	train-rmse:0.01599	eval-rmse:0.01796
# [1500]	train-rmse:0.01588	eval-rmse:0.01790
# [1550]	train-rmse:0.01579	eval-rmse:0.01786
# [1600]	train-rmse:0.01571	eval-rmse:0.01783
# [1650]	train-rmse:0.01561	eval-rmse:0.01778
# [1700]	train-rmse:0.01553	eval-rmse:0.01772
# [1750]	train-rmse:0.01543	eval-rmse:0.01766
# [1800]	train-rmse:0.01534	eval-rmse:0.01760
# [1850]	train-rmse:0.01526	eval-rmse:0.01757
# [1900]	train-rmse:0.01519	eval-rmse:0.01753
# [1950]	train-rmse:0.01511	eval-rmse:0.01748
# [2000]	train-rmse:0.01503	eval-rmse:0.01743
# [2050]	train-rmse:0.01495	eval-rmse:0.01737
# [2100]	train-rmse:0.01487	eval-rmse:0.01734
# [2150]	train-rmse:0.01480	eval-rmse:0.01731
# [2200]	train-rmse:0.01474	eval-rmse:0.01728
# [2250]	train-rmse:0.01466	eval-rmse:0.01725
# [2300]	train-rmse:0.01458	eval-rmse:0.01721
# [2350]	train-rmse:0.01450	eval-rmse:0.01716
# [2400]	train-rmse:0.01442	eval-rmse:0.01712
# [2450]	train-rmse:0.01435	eval-rmse:0.01708
# [2500]	train-rmse:0.01428	eval-rmse:0.01705
# [2550]	train-rmse:0.01422	eval-rmse:0.01703
# [2600]	train-rmse:0.01417	eval-rmse:0.01701
# [2650]	train-rmse:0.01411	eval-rmse:0.01699
# [2700]	train-rmse:0.01403	eval-rmse:0.01695
# [2750]	train-rmse:0.01395	eval-rmse:0.01691
# [2800]	train-rmse:0.01388	eval-rmse:0.01688
# [2850]	train-rmse:0.01381	eval-rmse:0.01684
# [2900]	train-rmse:0.01376	eval-rmse:0.01682
# [2950]	train-rmse:0.01370	eval-rmse:0.01679
# [3000]	train-rmse:0.01366	eval-rmse:0.01677
# [3050]	train-rmse:0.01358	eval-rmse:0.01674
# [3100]	train-rmse:0.01352	eval-rmse:0.01671
# [3150]	train-rmse:0.01347	eval-rmse:0.01668
# [3200]	train-rmse:0.01342	eval-rmse:0.01666
# [3250]	train-rmse:0.01337	eval-rmse:0.01664
# [3300]	train-rmse:0.01332	eval-rmse:0.01662
# [3350]	train-rmse:0.01327	eval-rmse:0.01660
# [3400]	train-rmse:0.01321	eval-rmse:0.01658
# [3450]	train-rmse:0.01315	eval-rmse:0.01656
# [3500]	train-rmse:0.01309	eval-rmse:0.01652
# [3550]	train-rmse:0.01303	eval-rmse:0.01649
# [3600]	train-rmse:0.01298	eval-rmse:0.01647
# [3650]	train-rmse:0.01293	eval-rmse:0.01645
# [3700]	train-rmse:0.01287	eval-rmse:0.01642
# [3750]	train-rmse:0.01277	eval-rmse:0.01636
# [3800]	train-rmse:0.01269	eval-rmse:0.01633
# [3850]	train-rmse:0.01264	eval-rmse:0.01631
# [3900]	train-rmse:0.01257	eval-rmse:0.01628
# [3950]	train-rmse:0.01253	eval-rmse:0.01626
# [3999]	train-rmse:0.01249	eval-rmse:0.01625
# [0]	train-rmse:0.15394	eval-rmse:0.14753
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:52:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.09960	eval-rmse:0.09560
# [100]	train-rmse:0.06871	eval-rmse:0.06631
# [150]	train-rmse:0.05199	eval-rmse:0.05081
# [200]	train-rmse:0.04292	eval-rmse:0.04256
# [250]	train-rmse:0.03791	eval-rmse:0.03808
# [300]	train-rmse:0.03486	eval-rmse:0.03535
# [350]	train-rmse:0.03277	eval-rmse:0.03356
# [400]	train-rmse:0.03141	eval-rmse:0.03243
# [450]	train-rmse:0.03053	eval-rmse:0.03168
# [500]	train-rmse:0.02982	eval-rmse:0.03106
# [550]	train-rmse:0.02907	eval-rmse:0.03044
# [600]	train-rmse:0.02864	eval-rmse:0.03007
# [650]	train-rmse:0.02821	eval-rmse:0.02971
# [700]	train-rmse:0.02777	eval-rmse:0.02935
# [750]	train-rmse:0.02737	eval-rmse:0.02905
# [800]	train-rmse:0.02702	eval-rmse:0.02879
# [850]	train-rmse:0.02672	eval-rmse:0.02855
# [900]	train-rmse:0.02645	eval-rmse:0.02835
# [950]	train-rmse:0.02624	eval-rmse:0.02820
# [1000]	train-rmse:0.02604	eval-rmse:0.02808
# [1050]	train-rmse:0.02579	eval-rmse:0.02791
# [1100]	train-rmse:0.02555	eval-rmse:0.02776
# [1150]	train-rmse:0.02534	eval-rmse:0.02765
# [1200]	train-rmse:0.02514	eval-rmse:0.02753
# [1250]	train-rmse:0.02493	eval-rmse:0.02741
# [1300]	train-rmse:0.02473	eval-rmse:0.02728
# [1350]	train-rmse:0.02456	eval-rmse:0.02717
# [1400]	train-rmse:0.02440	eval-rmse:0.02707
# [1450]	train-rmse:0.02425	eval-rmse:0.02699
# [1500]	train-rmse:0.02410	eval-rmse:0.02690
# [1550]	train-rmse:0.02396	eval-rmse:0.02683
# [1600]	train-rmse:0.02381	eval-rmse:0.02675
# [1650]	train-rmse:0.02365	eval-rmse:0.02665
# [1700]	train-rmse:0.02343	eval-rmse:0.02652
# [1750]	train-rmse:0.02328	eval-rmse:0.02642
# [1800]	train-rmse:0.02314	eval-rmse:0.02634
# [1850]	train-rmse:0.02304	eval-rmse:0.02629
# [1900]	train-rmse:0.02293	eval-rmse:0.02624
# [1950]	train-rmse:0.02282	eval-rmse:0.02620
# [2000]	train-rmse:0.02270	eval-rmse:0.02614
# [2050]	train-rmse:0.02257	eval-rmse:0.02607
# [2100]	train-rmse:0.02244	eval-rmse:0.02598
# [2150]	train-rmse:0.02233	eval-rmse:0.02593
# [2200]	train-rmse:0.02223	eval-rmse:0.02589
# [2250]	train-rmse:0.02213	eval-rmse:0.02584
# [2300]	train-rmse:0.02204	eval-rmse:0.02579
# [2350]	train-rmse:0.02193	eval-rmse:0.02573
# [2400]	train-rmse:0.02181	eval-rmse:0.02568
# [2450]	train-rmse:0.02170	eval-rmse:0.02562
# [2500]	train-rmse:0.02162	eval-rmse:0.02559
# [2550]	train-rmse:0.02151	eval-rmse:0.02555
# [2600]	train-rmse:0.02142	eval-rmse:0.02552
# [2650]	train-rmse:0.02132	eval-rmse:0.02550
# [2700]	train-rmse:0.02123	eval-rmse:0.02546
# [2750]	train-rmse:0.02114	eval-rmse:0.02542
# [2800]	train-rmse:0.02107	eval-rmse:0.02539
# [2850]	train-rmse:0.02101	eval-rmse:0.02538
# [2900]	train-rmse:0.02088	eval-rmse:0.02531
# [2950]	train-rmse:0.02077	eval-rmse:0.02525
# [3000]	train-rmse:0.02067	eval-rmse:0.02521
# [3050]	train-rmse:0.02058	eval-rmse:0.02517
# [3100]	train-rmse:0.02051	eval-rmse:0.02513
# [3150]	train-rmse:0.02041	eval-rmse:0.02507
# [3200]	train-rmse:0.02030	eval-rmse:0.02502
# [3250]	train-rmse:0.02019	eval-rmse:0.02496
# [3300]	train-rmse:0.02008	eval-rmse:0.02490
# [3350]	train-rmse:0.02001	eval-rmse:0.02485
# [3400]	train-rmse:0.01993	eval-rmse:0.02482
# [3450]	train-rmse:0.01989	eval-rmse:0.02480
# [3500]	train-rmse:0.01982	eval-rmse:0.02478
# [3550]	train-rmse:0.01974	eval-rmse:0.02475
# [3600]	train-rmse:0.01965	eval-rmse:0.02470
# [3650]	train-rmse:0.01956	eval-rmse:0.02464
# [3700]	train-rmse:0.01948	eval-rmse:0.02460
# [3750]	train-rmse:0.01937	eval-rmse:0.02454
# [3800]	train-rmse:0.01928	eval-rmse:0.02450
# [3850]	train-rmse:0.01923	eval-rmse:0.02448
# [3900]	train-rmse:0.01916	eval-rmse:0.02446
# [3950]	train-rmse:0.01909	eval-rmse:0.02443
# [3999]	train-rmse:0.01902	eval-rmse:0.02440
# [0]	train-rmse:0.09399	eval-rmse:0.08839
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [10:52:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.05980	eval-rmse:0.05650
# [100]	train-rmse:0.03976	eval-rmse:0.03803
# [150]	train-rmse:0.02828	eval-rmse:0.02761
# [200]	train-rmse:0.02175	eval-rmse:0.02173
# [250]	train-rmse:0.01796	eval-rmse:0.01829
# [300]	train-rmse:0.01562	eval-rmse:0.01617
# [350]	train-rmse:0.01393	eval-rmse:0.01454
# [400]	train-rmse:0.01271	eval-rmse:0.01339
# [450]	train-rmse:0.01165	eval-rmse:0.01230
# [500]	train-rmse:0.01075	eval-rmse:0.01138
# [550]	train-rmse:0.00992	eval-rmse:0.01050
# [600]	train-rmse:0.00925	eval-rmse:0.00979
# [650]	train-rmse:0.00871	eval-rmse:0.00923
# [700]	train-rmse:0.00816	eval-rmse:0.00863
# [750]	train-rmse:0.00782	eval-rmse:0.00826
# [800]	train-rmse:0.00752	eval-rmse:0.00795
# [850]	train-rmse:0.00731	eval-rmse:0.00772
# [900]	train-rmse:0.00710	eval-rmse:0.00751
# [950]	train-rmse:0.00693	eval-rmse:0.00734
# [1000]	train-rmse:0.00680	eval-rmse:0.00721
# [1050]	train-rmse:0.00670	eval-rmse:0.00712
# [1100]	train-rmse:0.00659	eval-rmse:0.00702
# [1150]	train-rmse:0.00650	eval-rmse:0.00694
# [1200]	train-rmse:0.00642	eval-rmse:0.00686
# [1250]	train-rmse:0.00635	eval-rmse:0.00680
# Validation Data: MAE: 11.193, R-Squared: 0.9966, RMSE: 22.6514, MSE: 513.0874 ,smape: 1.1994220633479462, mape: 1.2117
# Test Data: MAE: 10.7261, R-Squared: 0.9972, RMSE: 21.8282, MSE: 476.4721 ,smape: 1.1412139578816145, mape: 1.1457

# %%
def createAdditinalFeatures(X_scaled, xgb_models):
  #initialize a list to store the predicitions
    new_y_exp_scaled = []
    # Iterate over the model and generate the prediction
    for model in tqdm(xgb_models):
        predict_vals = model.predict(xgb.DMatrix(X_scaled))
        new_y_exp_scaled.append(predict_vals)

    new_y_exp_scaled_val = np.array(new_y_exp_scaled) # convert the prediction into a numpy array
    new_y_exp_scaled_val_transp = new_y_exp_scaled_val.T # transposing the predictions to make them concatenate with the original values
    a = X_scaled
    b = new_y_exp_scaled_val_transp
    results = []
    for f,t in zip(a,b):
        results.append(list(f)+list(t))

    additional_features =  np.array(results)
    return additional_features

# %%
additional_features = createAdditinalFeatures(X_scaled, xgb_models)
# Out:
# 100%|██████████| 7/7 [00:31<00:00,  4.56s/it]

# %% [markdown]
# **Combined model**

# %%
# Cross-Validation with Evaluation
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_epochs=200):
    fold = 1
    for train_index, val_index in kf.split(X_scaled):
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5, random_state=100) # 50/50 split of remaining 20%

        # Reshaping data for CNN
        X_train = X_train[..., np.newaxis]
        X_val = X_val[..., np.newaxis]
        X_test = X_test[..., np.newaxis]

        model = create_hybrid_model((X_train.shape[1], 1), y_train.shape[1])
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
        early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        model.summary()

        # Training
        history = model.fit(X_train, [y_train[:, i] for i in range(y_train.shape[1])],
                  validation_data=(X_val, [y_val[:, i] for i in range(y_val.shape[1])]),
                  epochs=num_epochs, batch_size=64, verbose=1, callbacks=[early_stopping])

        # Predictions
        y_train_pred = np.column_stack(model.predict(X_train))
        y_val_pred = np.column_stack(model.predict(X_val))
        y_test_pred = np.column_stack(model.predict(X_test)) #Prediction on test set

        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred)
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred) #Inverse transform for test set
        y_test_original = scaler_y.inverse_transform(y_test) #Inverse transform for test set

        # Enforce the rule after predictions for childcare expense
        # The issue is likely caused by X_train having an extra dimension due to[..., np.newaxis].
        # We need to select the original features for the condition
        y_train_pred_original[:, childcare_exp_col] = np.where(
            X_train[:, num_children_col, 0] == 0, 0, y_train_pred_original[:, childcare_exp_col]) #Using X_train[:, num_children_col, 0] instead of X_train[:, num_children_col]

        y_val_pred_original[:, childcare_exp_col] = np.where(
            X_val[:, num_children_col, 0] == 0, 0, y_val_pred_original[:, childcare_exp_col]) #Using X_val[:, num_children_col, 0] instead of X_val[:, num_children_col]

        y_test_pred_original[:, childcare_exp_col] = np.where(
            X_test[:, num_children_col, 0] == 0, 0, y_test_pred_original[:, childcare_exp_col]) #Using X_test[:, num_children_col, 0] instead of X_test[:, num_children_col]

        # Metrics for each target
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize()}:')
            print('Train Data:', regr_report(y_train_original[:, i], y_train_pred_original[:, i]))
            print('Validation Data:', regr_report(y_val_original[:, i], y_val_pred_original[:, i]))
            print('Test Data:', regr_report(y_test_original[:, i], y_test_pred_original[:, i])) #Print metrics for test set
            print()

       # Plot training & validation loss
        plt.figure(figsize=(8, 5))
        plt.plot(history.history['loss'], label='Training Loss', color='blue')
        plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title(f'Training vs Validation Loss (Fold {fold})')
        plt.legend()
        plt.show()

        fold += 1
        return model # Return the trained model
combined_model = cross_val_with_evaluation(additional_features, y_exp_scaled, kf) # the total number of inputs should be 18 ()
combined_model.save_weights("model_expenses.weights.h5")
# Out:
# Fold 1/5
# Model: "functional_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_15            │ (None, 18, 1)          │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_15 (Conv1D)        │ (None, 18, 8)          │             32 │ input_layer_15[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_15 (Flatten)      │ (None, 144)            │              0 │ conv1d_15[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_30 (Dense)          │ (None, 128)            │         18,560 │ flatten_15[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_31 (Dense)          │ (None, 64)             │          8,256 │ dense_30[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_housing (Dense)    │ (None, 1)              │             65 │ dense_31[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_food (Dense)       │ (None, 1)              │             65 │ dense_31[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_transportation     │ (None, 1)              │             65 │ dense_31[0][0]         │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_healthcare (Dense) │ (None, 1)              │             65 │ dense_31[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_othernecessities   │ (None, 1)              │             65 │ dense_31[0][0]         │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_childcare (Dense)  │ (None, 1)              │             65 │ dense_31[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_taxes (Dense)      │ (None, 1)              │             65 │ dense_31[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 27,303 (106.65 KB)
#  Trainable params: 27,303 (106.65 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0406 - target_childcare_loss: 0.0045 - target_food_loss: 0.0035 - target_healthcare_loss: 0.0087 - target_housing_loss: 0.0031 - target_othernecessities_loss: 0.0046 - target_taxes_loss: 0.0041 - target_transportation_loss: 0.0121 - val_loss: 0.0038 - val_target_childcare_loss: 3.8334e-04 - val_target_food_loss: 3.2677e-04 - val_target_healthcare_loss: 6.7701e-04 - val_target_housing_loss: 6.6538e-04 - val_target_othernecessities_loss: 2.5685e-04 - val_target_taxes_loss: 1.9290e-04 - val_target_transportation_loss: 0.0013
# Epoch 2/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0037 - target_childcare_loss: 4.9606e-04 - target_food_loss: 3.5937e-04 - target_healthcare_loss: 7.6906e-04 - target_housing_loss: 4.3665e-04 - target_othernecessities_loss: 2.4264e-04 - target_taxes_loss: 1.6106e-04 - target_transportation_loss: 0.0013 - val_loss: 0.0029 - val_target_childcare_loss: 4.0060e-04 - val_target_food_loss: 2.4572e-04 - val_target_healthcare_loss: 8.4049e-04 - val_target_housing_loss: 2.6348e-04 - val_target_othernecessities_loss: 1.7004e-04 - val_target_taxes_loss: 7.1405e-05 - val_target_transportation_loss: 9.5549e-04
# Epoch 3/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0032 - target_childcare_loss: 4.6803e-04 - target_food_loss: 2.5953e-04 - target_healthcare_loss: 7.6613e-04 - target_housing_loss: 3.6018e-04 - target_othernecessities_loss: 2.2110e-04 - target_taxes_loss: 8.1819e-05 - target_transportation_loss: 0.0011 - val_loss: 0.0028 - val_target_childcare_loss: 3.3063e-04 - val_target_food_loss: 1.7149e-04 - val_target_healthcare_loss: 5.9635e-04 - val_target_housing_loss: 4.5613e-04 - val_target_othernecessities_loss: 1.7524e-04 - val_target_taxes_loss: 7.5573e-05 - val_target_transportation_loss: 9.7257e-04
# Epoch 4/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.
# Test Data: MAE: 17.6592, R-Squared: 0.9893, RMSE: 23.4911, MSE: 551.8315 ,smape: 2.7239749584226804, mape: 2.7434
#
# Model Results for Childcare:
# Train Data: MAE: 54.4007, R-Squared: 0.9821, RMSE: 83.659, MSE: 6998.8251 ,smape: 5.178757286777353, mape: 5.3764
# Validation Data: MAE: 49.6895, R-Squared: 0.9858, RMSE: 74.9532, MSE: 5617.988 ,smape: 4.808034147081717, mape: 4.9696
# Test Data: MAE: 51.4653, R-Squared: 0.985, RMSE: 76.3233, MSE: 5825.2429 ,smape: 4.977241697841028, mape: 5.1599
#
# Model Results for Taxes:
# Train Data: MAE: 15.5328, R-Squared: 0.9967, RMSE: 23.5936, MSE: 556.6599 ,smape: 1.790969600973687, mape: 1.7915
# Validation Data: MAE: 15.3474, R-Squared: 0.9968, RMSE: 22.9293, MSE: 525.7509 ,smape: 1.7858113728747793, mape: 1.7866
# Test Data: MAE: 15.2718, R-Squared: 0.9969, RMSE: 22.7166, MSE: 516.046 ,smape: 1.7573669725022347, mape: 1.7566

# %%
# Cross-Validation with Evaluation
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_epochs=200):
    fold = 1
    test_data_storage = []  # List to store test data for all folds

    for train_index, val_index in kf.split(X_scaled):
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        # Splitting test and validation sets
        X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5, random_state=100)

        # Reshaping data for CNN
        X_train = X_train[..., np.newaxis]
        X_val = X_val[..., np.newaxis]
        X_test = X_test[..., np.newaxis]

        # Create and compile model
        model = create_hybrid_model((X_train.shape[1], 1), y_train.shape[1])
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

        model.summary()

        # Training
        model.fit(X_train, [y_train[:, i] for i in range(y_train.shape[1])],
                  validation_data=(X_val, [y_val[:, i] for i in range(y_val.shape[1])]),
                  epochs=num_epochs, batch_size=64, verbose=1, callbacks=[early_stopping])

        # Predictions
        y_test_pred = np.column_stack(model.predict(X_test))

        # Inverse scaling
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred)
        y_test_original = scaler_y.inverse_transform(y_test)

        # Enforce rule for childcare expense
        y_test_pred_original[:, childcare_exp_col] = np.where(
            X_test[:, num_children_col, 0] == 0, 0, y_test_pred_original[:, childcare_exp_col])

        # Store test data for this fold
        test_data = {
            "X_test": X_test,
            "y_test_original": y_test_original,
            "y_test_pred_original": y_test_pred_original
        }
        test_data_storage.append(test_data)

        # Metrics for each target
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize()} (Fold {fold}):')
            print('Test Data:', regr_report(y_test_original[:, i], y_test_pred_original[:, i]))

        fold += 1

    # Save the test data to a file
    with open('test_data.pkl', 'wb') as f:
        pickle.dump(test_data_storage, f)

    print("Test data has been saved to 'test_data.pkl'")
    return model

# Example usage
model_combine = cross_val_with_evaluation(additional_features, y_exp_scaled, kf)
model_combine.save_weights("test_model_expenses.weights.h5")
# Out:
# Fold 1/5
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5             │ (None, 18, 1)          │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_5 (Conv1D)         │ (None, 18, 8)          │             32 │ input_layer_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_5 (Flatten)       │ (None, 144)            │              0 │ conv1d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_10 (Dense)          │ (None, 128)            │         18,560 │ flatten_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_11 (Dense)          │ (None, 64)             │          8,256 │ dense_10[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_housing (Dense)    │ (None, 1)              │             65 │ dense_11[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_food (Dense)       │ (None, 1)              │             65 │ dense_11[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_transportation     │ (None, 1)              │             65 │ dense_11[0][0]         │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Model Results for Housing (Fold 5):
# Test Data: MAE: 56.8575, R-Squared: 0.9551, RMSE: 82.5089, MSE: 6807.7183 ,smape: 5.34108644539899, mape: 5.3434
# Model Results for Food (Fold 5):
# Test Data: MAE: 30.7774, R-Squared: 0.9803, RMSE: 47.8038, MSE: 2285.1985 ,smape: 3.509154945224765, mape: 3.5121
# Model Results for Transportation (Fold 5):
# Test Data: MAE: 63.6119, R-Squared: 0.8593, RMSE: 89.9063, MSE: 8083.1455 ,smape: 4.20025825709716, mape: 4.2772
# Model Results for Healthcare (Fold 5):
# Test Data: MAE: 62.6401, R-Squared: 0.9635, RMSE: 92.158, MSE: 8493.0981 ,smape: 5.171561968481866, mape: 5.1693
# Model Results for Othernecessities (Fold 5):
# Test Data: MAE: 21.5701, R-Squared: 0.9812, RMSE: 31.5265, MSE: 993.9184 ,smape: 3.204336006265698, mape: 3.1904
# Model Results for Childcare (Fold 5):
# Test Data: MAE: 60.5227, R-Squared: 0.9755, RMSE: 97.5809, MSE: 9522.0231 ,smape: 5.48716635545015, mape: 5.4378
# Model Results for Taxes (Fold 5):
# Test Data: MAE: 15.3998, R-Squared: 0.9966, RMSE: 24.0043, MSE: 576.2082 ,smape: 1.7574856408620825, mape: 1.747
# Test data has been saved to 'test_data.pkl'

# %% [markdown]
# **Model testing**

# %%
import pandas as pd
import numpy as np
import joblib
from tqdm import tqdm
# Load the scalers and test data
scaler_X = joblib.load('scaler_X.pkl')
scaler_y = joblib.load('scaler_y.pkl')
TEST_DATA = joblib.load('test_data.pkl')  # Loading the actual test data
if isinstance(TEST_DATA, list):
    TEST_DATA = pd.DataFrame(TEST_DATA)


test_data = TEST_DATA.head(3)
test_data
# Out:
#                                               X_test  \
# 0  [[[0.29599771297884503], [0.2789335226997628],...
# 1  [[[0.11120640365923384], [0.3591667877105491],...
# 2  [[[0.332590051457976], [0.29519644077188345], ...
#
#                                      y_test_original  \
# 0  [[1249.0, 872.0, 1701.0, 1107.0, 751.0, 1179.0...
# 1  [[772.0, 438.0, 1397.9999999999998, 642.0, 428...
# 2  [[1007.0, 1206.0, 1701.0, 1752.0, 784.0, 1113....
#
#                                 y_test_pred_original
# 0  [[1183.1417, 855.3601, 1697.267, 1143.5566, 71...
# 1  [[799.67615, 460.71082, 1328.8684, 655.9819, 4...
# 2  [[1001.35675, 1243.2594, 1721.1332, 1718.4153,...

# %%
import pandas as pd
import numpy as np
import joblib
from tqdm import tqdm

# Load the scalers and test data
scaler_X = joblib.load('scaler_X.pkl')
scaler_y = joblib.load('scaler_y.pkl')
TEST_DATA = joblib.load('test_data.pkl')  # Loading the actual test data

# Check if TEST_DATA is a list and convert it to DataFrame
if isinstance(TEST_DATA, list):
    TEST_DATA = pd.DataFrame(TEST_DATA)

# Extract the original values and predicted values from the test data
y_test_original = TEST_DATA['y_test_original'].values
y_test_pred_original = TEST_DATA['y_test_pred_original'].values

# Define the target columns
target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']

# Limit to 2 rows for output
for i, (true_val, pred_val) in enumerate(zip(y_test_original[:3], y_test_pred_original[:3])):  # Only process the first 2 rows
    print(f"\nRow {i+1}:")
    # Ensure j does not exceed the length of target_col_list or true_val/pred_val
    for j in range(min(len(target_col_list), len(true_val), len(pred_val))):
        # Accessing the first element of true and pred (assuming they are lists or arrays)
        print(f"{target_col_list[j]} - True: {true_val[j][0]:.2f}, Pred: {pred_val[j][0]:.2f}")
# Out:
# Row 1:
# housing - True: 1249.00, Pred: 1183.14
# food - True: 1130.00, Pred: 1116.52
# transportation - True: 960.00, Pred: 892.51
# healthcare - True: 1003.00, Pred: 1001.48
# othernecessities - True: 941.00, Pred: 945.70
# childcare - True: 1113.00, Pred: 1059.28
# taxes - True: 682.00, Pred: 646.71
#
# Row 2:
# housing - True: 772.00, Pred: 799.68
# food - True: 714.00, Pred: 684.80
# transportation - True: 1730.00, Pred: 1720.05
# healthcare - True: 766.00, Pred: 784.92
# othernecessities - True: 966.00, Pred: 1041.30
# childcare - True: 1427.00, Pred: 1336.78
# taxes - True: 825.00, Pred: 807.91
#
# Row 3:
# housing - True: 1007.00, Pred: 1001.36
# food - True: 1111.00, Pred: 1113.57
# transportation - True: 859.00, Pred: 742.95
# healthcare - True: 946.00, Pred: 875.13
# othernecessities - True: 851.00, Pred: 876.54
# childcare - True: 2543.00, Pred: 2533.17
# taxes - True: 1005.00, Pred: 1082.20

# %% [markdown]
# **Edge case testing**

# %%
# Load the scalers
scaler_X = joblib.load('scaler_X.pkl')
scaler_y = joblib.load('scaler_y.pkl')


def get_prediction(combined_model, input_data, scaler_X, scaler_y, xgb_models, num_children_col, childcare_exp_col):

    # Step 1: Create new features
    input_data_with_features = createFeatures(input_data.copy())

    # Step 2: Select relevant features
    X = input_data_with_features[['total', 'median_family_income', 'num_counties_in_st', 'n_children',
                                  'n_parents', 'n_members', 'per_member_cost', 'child_expense_cost',
                                  'parent_expense_cost', 'other_expense_cost','zero_childcare_cost']].values

    # Step 3: Scale the input data using the fitted scaler_X
    input_data_scaled = scaler_X.transform(X)

    # Step 4: Create Additional Features using XGBoost models
    additional_features = createAdditinalFeatures(input_data_scaled, xgb_models)

    # Reshape for the CNN layer (add the extra dimension)
    additional_features = additional_features[..., np.newaxis]  # Reshape additional_features

    # Step 5: Make predictions using the trained model
    # We need to unpack the predictions from the model output
    # Then, we can stack those into a single output array.
    input_data_pred = combined_model.predict(additional_features) # Predict on additional_features
    input_data_pred = np.column_stack(input_data_pred)

    # Step 6: Inverse transform the predictions to return them to the original scale
    input_data_pred_original = scaler_y.inverse_transform(input_data_pred)

    # Step 7: Enforce the rule that if there are no children, childcare cost is 0
    input_data_pred_original[:, childcare_exp_col] = np.where(
        input_data_with_features['n_children'].values == 0, 0, input_data_pred_original[:, childcare_exp_col]
    )

    return input_data_pred_original


def createFeatures(input_data):

    # Edge case testing (ADDITIONS)
    input_data["n_members"] = input_data["n_children"] + input_data["n_parents"]
    print("\nAltered Data (with corrected n_members):")
    print(input_data)
    # Step 1: Create additional features
    input_data["per_member_cost"] = input_data["total"] / input_data["n_members"]
    input_data["child_expense_cost"] = input_data["per_member_cost"] * input_data["n_children"]
    input_data["parent_expense_cost"] = input_data["per_member_cost"] * input_data["n_parents"]
    input_data["other_expense_cost"] = input_data["total"] - (input_data["child_expense_cost"] + input_data["parent_expense_cost"])

    # Step 2: Create binary column for whether there are children (0 if no children, 1 if there are children)
    input_data["zero_childcare_cost"] = input_data['n_children'].map(lambda x: 0 if x < 1 else 1)

    return input_data

def createAdditinalFeatures(X_scaled, xgb_models):
    #initialize a list to store the predicitions
    new_y_exp_scaled = []
    # Iterate over the model and generate the prediction
    for model in tqdm(xgb_models):
        predict_vals = model.predict(xgb.DMatrix(X_scaled))
        new_y_exp_scaled.append(predict_vals)

    new_y_exp_scaled_val = np.array(new_y_exp_scaled) # convert the prediction into a numpy array
    new_y_exp_scaled_val_transp = new_y_exp_scaled_val.T # transposing the predictions to make them concatenate with the original values
    a = X_scaled
    b = new_y_exp_scaled_val_transp
    results = []
    for f,t in zip(a,b):
        results.append(list(f)+list(t))

    additional_features =  np.array(results)
    return additional_features

# Example of input data to test predictions
input_data = pd.DataFrame(
    [[4850, 4938.42, 254, 1, 1, 3]],
    columns=['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents', 'n_members']
)

print("\nUser inserted data: ")
print(input_data)

# Assuming `model_combine` is your trained model
input_data_pred_original = get_prediction(combined_model, input_data, scaler_X, scaler_y, xgb_models, num_children_col=3, childcare_exp_col=5)
print (input_data_pred_original)

# Print predictions
target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']
for i, prediction in enumerate(input_data_pred_original[0]):
    print(f"{target_col_list[i]}: {prediction:.2f}")
# Out:
# User inserted data:
#    total  median_family_income  num_counties_in_st  n_children  n_parents  \
# 0   4850               4938.42                 254           1          1
#
#    n_members
# 0          3
#
# Altered Data (with corrected n_members):
#    total  median_family_income  num_counties_in_st  n_children  n_parents  \
# 0   4850               4938.42                 254           1          1
#
#    n_members
# 0          2
# 100%|██████████| 7/7 [00:00<00:00, 171.98it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# [[ 850.1933   467.4292  1404.2478   695.49664  465.80292  556.11334
#    474.7817 ]]
# housing: 850.19
# food: 467.43
# transportation: 1404.25
# healthcare: 695.50
# othernecessities: 465.80
# childcare: 556.11
# taxes: 474.78

# %% [markdown]
# **Model 2: TabNet Regressor with LIME and Counterfactual Explanation**

# %% [markdown]
# **Importing necessary libraries**

# %%
# !pip install lime
# !pip install dice-ml
# !pip install pytorch_tabnet

# %% [markdown]
# **Data preprocessing**

# %%
from sklearn.model_selection import train_test_split
y_expenses = household_dataset[['median_family_income','housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']]
household_income_sufficiency = household_dataset[['financial_stability']].values

scaler_y_stability = MinMaxScaler()
household_income_sufficiency = scaler_y_stability.fit_transform(household_income_sufficiency)


# 80/10/10 split for TabNet
X_train_tabnet, X_rem, y_exp_train_tabnet, y_exp_rem, y_stab_train_tabnet, y_stab_rem = train_test_split(
    X, y_expenses, household_income_sufficiency, test_size=0.2, random_state=100)

X_test_tabnet, X_val_tabnet, y_exp_test_tabnet, y_exp_val_tabnet, y_stab_test_tabnet, y_stab_val_tabnet = train_test_split(
    X_rem, y_exp_rem, y_stab_rem, test_size=0.5, random_state=100)

# %% [markdown]
# **Model training**

# %%
# TabNet Model for Financial Stability Prediction
from pytorch_tabnet.tab_model import TabNetRegressor
tabnet_stab = TabNetRegressor()
tabnet_stab.fit(
    y_exp_train_tabnet.values, y_stab_train_tabnet.reshape(-1, 1),
    eval_set=[(y_exp_val_tabnet.values, y_stab_val_tabnet.reshape(-1, 1)), (y_exp_test_tabnet.values, y_stab_test_tabnet.reshape(-1, 1))],
    max_epochs=120,
    patience=10,
    batch_size=1024,
    virtual_batch_size=128,
    num_workers=0
)

tabnet_stab.save_model("tabnet_stability.pth")

# %% [markdown]
# **Model evaluation**

# %%
y_stab_pred_test = tabnet_stab.predict(y_exp_test_tabnet.values)

# Evaluation Function
def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    return {'MAE': mae, 'MSE': mse, 'RMSE': rmse, 'R2': r2, 'MAPE': mape}



# Evaluate Results
stability_results = evaluate_model(y_stab_test_tabnet.reshape(-1, 1), y_stab_pred_test)

print("Test evaluation for the tabnetregressor:", stability_results)

# %% [markdown]
# **Test the predictions**

# %%
# Rescale predictions back to original scale
y_stab_pred_test_rescaled = scaler_y_stability.inverse_transform(y_stab_pred_test)
y_stab_test_rescaled = scaler_y_stability.inverse_transform(y_stab_test_tabnet)

# Print Predictions and Actual Values
print("Predicted Financial Stability (Test Set):", y_stab_pred_test_rescaled.flatten())
print("Actual Financial Stability (Test Set):", y_stab_test_rescaled.flatten())

# %% [markdown]
# **XAI Technique: LIME**

# %%
# LIME for Explainability
from lime.lime_tabular import LimeTabularExplainer
explainer = LimeTabularExplainer(
    training_data=y_exp_train_tabnet.values,
    feature_names=y_exp_train_tabnet.columns.tolist(),
    class_names=y_exp_train_tabnet.columns.tolist(),
    mode='regression'
)

data_row = [5227.250000,864, 584, 1339, 791, 513,0,661]

data_row = np.array(data_row) # This line is added to convert the list into a numpy array
exp = explainer.explain_instance(
    data_row=data_row,  # Use 1D data here
    predict_fn=tabnet_stab.predict
)


# Display Explanation
print("\nLIME Explanation:")


# # Plot Explanation
exp.show_in_notebook(show_table=True)

# %% [markdown]
# **XAI Technique 2: Counterfactual Explanation**

# %%
counterfactual_input_cols = ['median_family_income','housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes','financial_stability']

# %%
y_exp_test_tabnet

# %%
new_test_with_indicator= y_exp_test_tabnet.copy()
new_test_with_indicator["financial_stability"] = y_stab_test_tabnet

# %%
new_test_with_indicator

# %%
continuous_features=counterfactual_input_cols
outcome_name='financial_stability'

query_instance = pd.DataFrame(
              [data_row],
              columns=counterfactual_input_cols[:-1]
        )

# %%
from dice_ml import Data, Model as Modeldice
import dice_ml
# Initialize DiCE for Counterfactual Explanations
data_dice = dice_ml.Data(
    dataframe=new_test_with_indicator,
    continuous_features=y_exp_test_tabnet.columns.tolist(),
    outcome_name='financial_stability'
)


# Wrap the TabNet Stability Model for DiCE
class TabNetWrapper:
    def __init__(self, model):
        self.model = model

    def predict(self, input_data):
        input_data = np.array(input_data)
        return self.model.predict(input_data)

dice_model = Modeldice(model=TabNetWrapper(tabnet_stab), backend="sklearn",  model_type='regressor')

# Generate Counterfactuals
# query_instance = y_exp_test_tabnet.iloc[[0]][y_exp_train_tabnet.columns.tolist()]
counterfactuals = dice_ml.Dice(data_dice, dice_model, method="random")

# Generate 3 diverse counterfactuals
cf = counterfactuals.generate_counterfactuals(query_instance,
                                              total_CFs=3,
                                              desired_range=[0.6, 1.0])  # Desired stability range

# Display Counterfactuals
print("\nCounterfactual Explanations:")
cf.visualize_as_dataframe(show_only_changes=True)
